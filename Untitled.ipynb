# %%
#importing relevant libraries and packages
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
from sklearn.svm import SVC
from sklearn.pipeline import Pipeline
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import confusion_matrix
from sklearn.metrics import accuracy_score
from sklearn.metrics import classification_report
import sklearn.metrics as metrics
from sklearn.metrics import make_scorer
from sklearn.metrics import precision_score,recall_score,f1_score,roc_auc_score
from mpl_toolkits.mplot3d import Axes3D
#choosing to ignore warning messages 
import warnings
warnings.filterwarnings("ignore")

# %%
#Uploading the Mammographic mass dataset from the UCI repository
url = 'http://archive.ics.uci.edu/ml/machine-learning-databases/mammographic-masses/mammographic_masses.data'

#Specifying the column names
column_names = ["BI-RADS assessment", "age", "mass_shape","mass_margin","mass_density","severity_class"]

#Reading the dataset into a pandas DataFrame
df = pd.read_csv(url, header=None, names=column_names)

#Viewing the top 5 rows of the dataset
df.head(5)
# Out:
#   BI-RADS assessment age mass_shape mass_margin mass_density  severity_class
# 0                  5  67          3           5            3               1
# 1                  4  43          1           1            ?               1
# 2                  5  58          4           5            3               1
# 3                  4  28          1           1            3               0
# 4                  5  74          1           5            ?               1

# %%
#Using df.info() function to determine the type of data in the columns
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 961 entries, 0 to 960
# Data columns (total 6 columns):
# BI-RADS assessment    961 non-null object
# age                   961 non-null object
# mass_shape            961 non-null object
# mass_margin           961 non-null object
# mass_density          961 non-null object
# severity_class        961 non-null int64
# dtypes: int64(1), object(5)
# memory usage: 45.1+ KB

# %%
#viewing the column names
df.columns
# Out:
# Index(['BI-RADS assessment', 'age', 'mass_shape', 'mass_margin',
#        'mass_density', 'severity_class'],
#       dtype='object')

# %%
#Null values are shwon as '?', replacing all null values with an empty space
df.replace(regex=True,inplace=True,to_replace=r'\D',value=r'')
df.head(5)
# Out:
#   BI-RADS assessment age mass_shape mass_margin mass_density  severity_class
# 0                  5  67          3           5            3               1
# 1                  4  43          1           1                            1
# 2                  5  58          4           5            3               1
# 3                  4  28          1           1            3               0
# 4                  5  74          1           5                            1

# %%
#Converting all values from object data type to a numeric value either integer or float
df = df.apply(pd.to_numeric, errors ='ignore')

# %%
#Checking that the data type has been changed
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 961 entries, 0 to 960
# Data columns (total 6 columns):
# BI-RADS assessment    959 non-null float64
# age                   956 non-null float64
# mass_shape            930 non-null float64
# mass_margin           913 non-null float64
# mass_density          885 non-null float64
# severity_class        961 non-null int64
# dtypes: float64(5), int64(1)
# memory usage: 45.1 KB

# %%
#Using .describe function to get an overview of the descriptive statistics of all of the attibutes and target class values
df.describe()
# Out:
#        BI-RADS assessment         age  mass_shape  mass_margin  mass_density  \
# count          959.000000  956.000000  930.000000   913.000000    885.000000
# mean             4.348279   55.487448    2.721505     2.796276      2.910734
# std              1.783031   14.480131    1.242792     1.566546      0.380444
# min              0.000000   18.000000    1.000000     1.000000      1.000000
# 25%              4.000000   45.000000    2.000000     1.000000      3.000000
# 50%              4.000000   57.000000    3.000000     3.000000      3.000000
# 75%              5.000000   66.000000    4.000000     4.000000      3.000000
# max             55.000000   96.000000    4.000000     5.000000      4.000000
#
#        severity_class
# count      961.000000
# mean         0.463059
# std          0.498893
# min          0.000000
# 25%          0.000000
# 50%          0.000000
# 75%          1.000000
# max          1.000000

# %%
#getting the mode values for all of the attributes and the target class.
df.mode()
# Out:
#    BI-RADS assessment   age  mass_shape  mass_margin  mass_density  \
# 0                 4.0  59.0         4.0          1.0           3.0
#
#    severity_class
# 0               0

# %%
#The BI-RADS assessment feature is non-predictive and will be dropped.
df = df.drop(columns=["BI-RADS assessment"])
df.head()
# Out:
#     age  mass_shape  mass_margin  mass_density  severity_class
# 0  67.0         3.0          5.0           3.0               1
# 1  43.0         1.0          1.0           NaN               1
# 2  58.0         4.0          5.0           3.0               1
# 3  28.0         1.0          1.0           3.0               0
# 4  74.0         1.0          5.0           NaN               1

# %%
#Finding the number of missing values in each column
df.isnull().sum()
# Out:
# age                5
# mass_shape        31
# mass_margin       48
# mass_density      76
# severity_class     0
# dtype: int64

# %%
#age is a continuous ordinal variable so we can replace null values with mean age values
df.age.fillna(df.age.mean(), inplace=True)

# %%
#Null values from the age feature column have been imputed
df.isnull().sum()
# Out:
# age                0
# mass_shape        31
# mass_margin       48
# mass_density      76
# severity_class     0
# dtype: int64

# %%
#Dropping all rows with null values
df = df.dropna()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 836 entries, 0 to 960
# Data columns (total 5 columns):
# age               836 non-null float64
# mass_shape        836 non-null float64
# mass_margin       836 non-null float64
# mass_density      836 non-null float64
# severity_class    836 non-null int64
# dtypes: float64(4), int64(1)
# memory usage: 39.2 KB

# %%
#Checking that the DataFrame dose not have any null values
df.isnull().sum()
# Out:
# age               0
# mass_shape        0
# mass_margin       0
# mass_density      0
# severity_class    0
# dtype: int64

# %%
#Getting dummy variables for the attributes that have nominal values
df2 = pd.get_dummies(data=df, columns=['mass_shape', 'mass_margin'])

# %%
df2.columns
# Out:
# Index(['age', 'mass_density', 'severity_class', 'mass_shape_1.0',
#        'mass_shape_2.0', 'mass_shape_3.0', 'mass_shape_4.0', 'mass_margin_1.0',
#        'mass_margin_2.0', 'mass_margin_3.0', 'mass_margin_4.0',
#        'mass_margin_5.0'],
#       dtype='object')

# %%
df2 = df2[['age', 'mass_density', 'mass_shape_1.0',
       'mass_shape_2.0', 'mass_shape_3.0', 'mass_shape_4.0', 'mass_margin_1.0',
       'mass_margin_2.0', 'mass_margin_3.0', 'mass_margin_4.0',
       'mass_margin_5.0','severity_class']]

# %%
#Checking the shape of the DataFrame
df2.shape
# Out:
# (836, 12)

# %%
# Checking the column names of the DataFrame with the newly added dummy variables
df2.columns
# Out:
# Index(['age', 'mass_density', 'mass_shape_1.0', 'mass_shape_2.0',
#        'mass_shape_3.0', 'mass_shape_4.0', 'mass_margin_1.0',
#        'mass_margin_2.0', 'mass_margin_3.0', 'mass_margin_4.0',
#        'mass_margin_5.0', 'severity_class'],
#       dtype='object')

# %%
#Visualising the distribution of the age of the patients using histogram, boxplot and violinplot
plt.figure(figsize=(20,10))

plt.subplot(1,3,1)
plt.hist(df.age,histtype='bar',bins=15, color = 'teal') 
plt.grid(True)
plt.xlabel('Age',fontsize = 14)
plt.ylabel('Number of patients', fontsize=14)
plt.title("Distribution of the age of patient's included in the dataset",fontsize=15)

plt.subplot(1,3,2)
plt.boxplot(df.age,notch = True)
plt.grid(color='grey', linestyle='-', linewidth=0.5)
plt.ylabel('Age',fontsize=14)
plt.title("Boxplot of the patient's age values",fontsize =15)

plt.subplot(1,3,3)
plt.violinplot(df.age, showmeans=True, showextrema=True)
plt.grid(b=None,color='grey', linestyle='-', linewidth=0.5,axis = 'y')
plt.ylabel('Age',fontsize=14)
plt.title("Violinplot of the patients age values",fontsize=15)

plt.show()

# %%
#Visualising the distribution of the mass shape values using histogram, boxplot and violinplot
plt.figure(figsize=(20,10))

plt.subplot(1,3,1)
plt.hist(df.mass_shape,histtype='bar',bins=7, color = 'teal') 
plt.grid(True)
plt.xlabel('Mass shape',fontsize = 14)
plt.ylabel('Number of patients', fontsize=14)
plt.title("Distribution of the mass shape values",fontsize=15)


plt.subplot(1,3,2)
plt.boxplot(df.mass_shape,notch = True)
plt.grid(color='grey', linestyle='-', linewidth=0.5)
plt.ylabel('Mass shape',fontsize=14)
plt.title("Boxplot of the mass shape values",fontsize =15)

plt.subplot(1,3,3)
plt.violinplot(df.mass_shape, showmeans=True, showextrema=True)
plt.grid(b=None,color='grey', linestyle='-', linewidth=0.5,axis = 'y')
plt.ylabel('Mass shape',fontsize=14)
plt.title("Violinplot of the mass shape values",fontsize=15)

plt.show()

# %%
#Visualising the distribution of the mass margin values using histogram, boxplot and violinplot
plt.figure(figsize=(20,10))

plt.subplot(1,3,1)
plt.hist(df.mass_margin,histtype='bar',bins=7, color = 'teal') 
plt.grid(True)
plt.xlabel('Mass margin',fontsize = 14)
plt.ylabel('Number of patients', fontsize=14)
plt.title("Distribution of the mass smargin values",fontsize=15)


plt.subplot(1,3,2)
plt.boxplot(df.mass_margin,notch = True)
plt.grid(color='grey', linestyle='-', linewidth=0.5)
plt.ylabel('Mass margin',fontsize=14)
plt.title("Boxplot of the mass margin values",fontsize =15)

plt.subplot(1,3,3)
plt.violinplot(df.mass_margin, showmeans=True, showextrema=True)
plt.grid(b=None,color='grey', linestyle='-', linewidth=0.5,axis = 'y')
plt.ylabel('Mass margin',fontsize=14)
plt.title("Violinplot of the mass margin values",fontsize=15)

plt.show()

# %%
#Visualising the distribution of the mass density values using histogram, boxplot and violinplot
plt.figure(figsize=(25,10))

plt.subplot(1,3,1)
plt.hist(df.mass_density,histtype='bar',bins=7, color = 'teal') 
plt.grid(True)
plt.xlabel('Mass density',fontsize = 14)
plt.ylabel('Number of patients', fontsize=14)
plt.title("Distribution of the mass density values",fontsize=15)


plt.subplot(1,3,2)
plt.boxplot(df.mass_density,notch = True)
plt.grid(color='grey', linestyle='-', linewidth=0.5)
plt.ylabel('Mass density',fontsize=14)
plt.title("Boxplot of the mass density values",fontsize =15)

plt.subplot(1,3,3)
plt.violinplot(df.mass_density, showmeans=True, showextrema=True)
plt.grid(b=None,color='grey', linestyle='-', linewidth=0.5,axis = 'y')
plt.ylabel('Mass density',fontsize=14)
plt.title("Violinplot of the mass density values",fontsize=15)

plt.show()

# %%
#Visualising the boxplots of all of the attributes
df.plot(kind='box', subplots=True, layout=(3,3), sharex=False, sharey=False, figsize=(20,16), grid = True, notch = True)
# Out:
# age                  AxesSubplot(0.125,0.657941;0.227941x0.222059)
# mass_shape        AxesSubplot(0.398529,0.657941;0.227941x0.222059)
# mass_margin       AxesSubplot(0.672059,0.657941;0.227941x0.222059)
# mass_density         AxesSubplot(0.125,0.391471;0.227941x0.222059)
# severity_class    AxesSubplot(0.398529,0.391471;0.227941x0.222059)
# dtype: object

# %%
#Visalising the distribution of all of the attributes using histograms
df.hist(figsize=(20,16),bins = 10 )
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000001EF6BB1C080>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001EF6BC0E518>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x000001EF6AD03898>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001EF6AD28E10>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x000001EF6AD563C8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001EF6AD79940>]],
#       dtype=object)

# %%
#Plotting the mass margin, mass shape and mass density features in a 3D space
import matplotlib.pyplot as plt

feature1 = df['mass_shape'].values
feature2 = df['mass_density'].values 
feature3 = df['mass_margin'].values

df['severity_class']=df['severity_class'].astype('str')

c = df['severity_class'].values
df['severity_class']= df['severity_class'].astype('int')
c[c=='0'] = 'b' #benign
c[c=='1'] = 'r' #malignant

fig = plt.figure(figsize=(14,8))
ax = fig.add_subplot(111, projection='3d')
ax.scatter(feature1, feature2, feature3, c=c)
ax.set_xlabel('Mass shape')
ax.set_ylabel('Mass density')
ax.set_zlabel('Mass margin')

plt.show()

# %%
import seaborn as sns
sns.catplot(x= "mass_density", y="age", hue = "severity_class", kind= "swarm", data=df)

# %%
import seaborn as sns
sns.catplot(x= "mass_shape", y="age", hue = "severity_class", kind= "swarm", data=df)

# %%
import seaborn as sns
sns.catplot(x= "mass_margin", y="age", hue = "severity_class", kind= "swarm", data=df)

# %%
import seaborn as sns
sns.catplot(x= "severity_class", y="age", hue = "severity_class", kind= "swarm", data=df)

# %%
import seaborn as sns
sns.catplot(x= "severity_class", y="mass_density", hue = "severity_class", kind= "swarm", data=df);

# %%
df2.corr()
# Out:
#                       age  mass_density  mass_shape_1.0  mass_shape_2.0  \
# age              1.000000      0.052338       -0.246116       -0.211287
# mass_density     0.052338      1.000000       -0.016310       -0.081986
# mass_shape_1.0  -0.246116     -0.016310        1.000000       -0.286282
# mass_shape_2.0  -0.211287     -0.081986       -0.286282        1.000000
# mass_shape_3.0   0.043475     -0.013622       -0.178920       -0.172806
# mass_shape_4.0   0.356301      0.089653       -0.499748       -0.482669
# mass_margin_1.0 -0.438535     -0.127303        0.552555        0.340302
# mass_margin_2.0  0.046612      0.019618       -0.056921        0.000321
# mass_margin_3.0  0.103038      0.030142       -0.173818       -0.087222
# mass_margin_4.0  0.224302      0.048237       -0.300117       -0.134505
# mass_margin_5.0  0.188792      0.073446       -0.175495       -0.207100
# class            0.455240      0.068328       -0.344825       -0.329041
#
#                  mass_shape_3.0  mass_shape_4.0  mass_margin_1.0  \
# age                    0.043475        0.356301        -0.438535
# mass_density          -0.013622        0.089653        -0.127303
# mass_shape_1.0        -0.178920       -0.499748         0.552555
# mass_shape_2.0        -0.172806       -0.482669         0.340302
# mass_shape_3.0         1.000000       -0.301658        -0.076634
# mass_shape_4.0        -0.301658        1.000000        -0.701567
# mass_margin_1.0       -0.076634       -0.701567         1.000000
# mass_margin_2.0        0.092946       -0.007619        -0.133513
# mass_margin_3.0        0.081095        0.170368        -0.302586
# mass_margin_4.0        0.027662        0.347748        -0.526530
# mass_margin_5.0       -0.049377        0.348588        -0.336109
# class                  0.022068        0.549627        -0.579854
#
#                  mass_margin_2.0  mass_margin_3.0  mass_margin_4.0  \
# age                     0.046612         0.103038         0.224302
# mass_density            0.019618         0.030142         0.048237
# mass_shape_1.0         -0.056921        -0.173818        -0.300117
# mass_shape_2.0          0.000321        -0.087222        -0.134505
# mass_shape_3.0          0.092946         0.081095         0.027662
# mass_shape_4.0         -0.007619         0.170368         0.347748
# mass_margin_1.0        -0.133513        -0.302586        -0.526530
# mass_margin_2.0         1.000000        -0.064512        -0.112258
# mass_margin_3.0        -0.064512         1.000000        -0.254415
# mass_margin_4.0        -0.112258        -0.254415         1.000000
# mass_margin_5.0        -0.071659        -0.162405        -0.282601
# class                   0.056450         0.112558         0.278461
#
#                  mass_margin_5.0     class
# age                     0.188792  0.455240
# mass_density            0.073446  0.068328
# mass_shape_1.0         -0.175495 -0.344825
# mass_shape_2.0         -0.207100 -0.329041
# mass_shape_3.0         -0.049377  0.022068
# mass_shape_4.0          0.348588  0.549627
# mass_margin_1.0        -0.336109 -0.579854
# mass_margin_2.0        -0.071659  0.056450
# mass_margin_3.0        -0.162405  0.112558
# mass_margin_4.0        -0.282601  0.278461
# mass_margin_5.0         1.000000  0.297182
# class                   0.297182  1.000000

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns

fig, ax = plt.subplots(figsize=(16,16))  
corr1 = df2.corr()
ax = sns.heatmap(corr1, annot = True, cmap="coolwarm")

plt.setp(ax.axes.get_xticklabels(), rotation=45)
plt.tight_layout()
plt.title('Correlation Matrix for mammographic masses dataset',fontsize = 20)
# Out:
# Text(0.5, 1.0, 'Correlation Matrix for mammographic masses dataset')

# %%
# Creating the input variable for the classifiers
X = df2.drop('severity_class',axis = 1) # selecting the feature colums, only excluding the target coulumn 'class'
y = df2['severity_class']

# %%
#determining the class distribution
print ("number of all feature vectors:", y.size)
print ("number of malignant feature vectors: ", np.sum(y))
print ("number of benign feature vectors: ",  y.size-np.sum(y))
# Out:
# number of all feature vectors: 836
# number of malignant feature vectors:  408
# number of benign feature vectors:  428

# %%
#Determining the class distribution as a percentage
benign_data_raw = y[y == 0]
malign_data_raw = y[y == 1]

percentage = len(malign_data_raw)/float(len(benign_data_raw))
sample_size = int(percentage*len(benign_data_raw))


print ("\nPercentage of benign tumours            :", len(benign_data_raw) / float(len(y)))
print ("Percentage of malign tumours            :", len(malign_data_raw) / float(len(y)))
print ("\nTotal number of data in our new dataset :", len(y))
# Out:
# Percentage of benign tumours            : 0.5119617224880383
# Percentage of malign tumours            : 0.4880382775119617
#
# Total number of data in our new dataset : 836

# %%
#Importing train test split module
from sklearn.model_selection import train_test_split

#Spliting the data into training and testing sets, 80% of data will be used for training and 20% of data is kept aside for testing
X_train, X_test, y_train, y_test = \
    train_test_split(X, y, 
                     test_size=0.20,
                     stratify=y,
                     random_state=1)

# %%
#Calculating the variance explained number of different feature components
pca = PCA()
X_train_pca = pca.fit_transform(X_train)
pca.explained_variance_ratio_
# Out:
# array([2.74754440e-01, 1.30298066e-01, 1.16741787e-01, 1.11016623e-01,
#        1.01934003e-01, 8.72163540e-02, 8.53220884e-02, 6.63814110e-02,
#        2.63352279e-02, 9.53971769e-33, 2.10407214e-33])

# %%
#Plotting the The variance explained ratio and the cumulative variance
plt.bar(np.arange(11), pca.explained_variance_ratio_, alpha=0.5, color = 'teal', align='center',label='individual explained variance')
plt.step(np.arange(11), np.cumsum(pca.explained_variance_ratio_), where='mid',label='cumulative explained variance')
plt.ylabel('Explained variance ratio')
plt.xlabel('Number of principal components')
plt.grid(True)
plt.legend(loc='best')
plt.title('Explained variance by principal components')
plt.show()

# %%
#Determining the effect that different number of PCA components have on the model accuracy
def plotvector(X_train, y_train, X_test, y_test):
    results = []
    
    for i in range(1, 11):
        pipe_knn = Pipeline([('scl', StandardScaler()),
                             ('pca', PCA(n_components=i)),
                             ('clf', SVC(probability=True, verbose = False))])
        
        pipe_knn.fit(X_train, y_train)
        results.append([i, pipe_knn.score(X_test, y_test)])
 
    return np.array(results)

PCA_accuracy =  plotvector(X_train, y_train, X_test, y_test)
PCA_accuracy
# Out:
# array([[ 1.        ,  0.76190476],
#        [ 2.        ,  0.74404762],
#        [ 3.        ,  0.76190476],
#        [ 4.        ,  0.75595238],
#        [ 5.        ,  0.75      ],
#        [ 6.        ,  0.75595238],
#        [ 7.        ,  0.75595238],
#        [ 8.        ,  0.73809524],
#        [ 9.        ,  0.74404762],
#        [10.        ,  0.74404762]])

# %%
#Plotting the accuracy of the model with different number of PCA components
plt.plot(PCA_accuracy[:,0], PCA_accuracy[:,1], color='b', label='ACC')
plt.legend(loc=3)
plt.ylim(0.6, 0.9)
plt.grid(True)
plt.title("Accuracy with increasing principal component")
plt.show()

# %%
pipelines = []

# %%
#Put together the Support Vector Classifier Pipeline
pipe_svc = Pipeline([('scl', StandardScaler()),
                     ('pca',PCA(n_components = 3)),
                    ('clf',SVC(probability=True, verbose = False))])

#Fit the pipeline to the training data
pipe_svc.fit(X_train, y_train)

scores = cross_val_score(estimator=pipe_svc, X=X_train, y=y_train, cv=10, n_jobs=1, verbose=0)
print('--> Model Training Accuracy: %.3f +/- %.3f' %(np.mean(scores), np.std(scores)))

pipelines.append(( 'svc_pipeline', pipe_svc))
# Out:
# --> Model Training Accuracy: 0.812 +/- 0.049

# %%
#Put together the Support Vector Classifier Pipeline without PCA
pipe_svc_no_PCA = Pipeline([('scl', StandardScaler()),
                    ('clf',SVC(probability=True, verbose = False))])

#Fit the pipeline to the training data
pipe_svc_no_PCA.fit(X_train, y_train)

scores = cross_val_score(estimator=pipe_svc_nopca, X=X_train, y=y_train, cv=10, n_jobs=1, verbose=0)

print('--> Model Training Accuracy: %.3f +/- %.3f' %(np.mean(scores), np.std(scores)))
pipelines.append(('svc_pipeline_no_PCA', pipe_svc_no_PCA))
# Out:
# --> Model Training Accuracy: 0.803 +/- 0.054

# %%
#Tuning hyperparameters, specifing a range of values for the GridSearch to select the optimal hyperparamater values
param_range = [0.001, 0.01, 0.1, 1.0, 10.0, 100.0, 1000.0]


param_grid = [{'clf__C': param_range,'clf__kernel': ['linear']},
              {'clf__C': param_range,'clf__gamma': param_range,
               'clf__kernel': ['rbf'] }]


#Using GridSearch to optimise for Accuracy
gs = GridSearchCV(estimator=pipe_svc,
                  param_grid=param_grid,
                  scoring='accuracy',
                  cv=10,
                  n_jobs=1)

#Fitting Gridsearch to the training data
gs = gs.fit(X_train, y_train)
print('--> Tuned Parameters Best Score: ', gs.best_score_)
print('--> Best Parameters: \n',gs.best_params_)
# Out:
# --> Tuned Parameters Best Score:  0.8233532934131736
# --> Best Parameters:
#  {'clf__C': 0.001, 'clf__kernel': 'linear'}

# %%
#Use best parameters
clf_svc_accuracy= gs_svc_accuracy.best_estimator_

#Get Final Scores
clf_svc_accuracy.fit(X_train, y_train)
scores = cross_val_score(estimator=clf_svc_accuracy,
                         X=X_train,
                         y=y_train,
                         cv=10,
                         n_jobs=1)
print('--> Final Model Training Accuracy: %.3f +/- %.3f' %(np.mean(scores), np.std(scores)))

print('--> Final Accuracy on Test set: %.5f' % clf_svc_accuracy.score(X_test,y_test))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-199-458448f842c7> in <module>
#       1 #Use best parameters
# ----> 2 clf_svc_accuracy= gs_svc_accuracy.best_estimator_
#       3
#       4 #Get Final Scores
#       5 clf_svc_accuracy.fit(X_train, y_train)
#
# AttributeError: 'GridSearchCV' object has no attribute 'best_estimator_'

# %%
clf_svc_accuracy.fit(X_train, y_train)
y_pred_accuracy = clf_svc_accuracy.predict(X_test)
confmat_acc = confusion_matrix(y_true=y_test, y_pred=y_pred_accuracy)
print(accuracy_score(y_test, y_pred_accuracy))
print(confusion_matrix(y_test, y_pred_accuracy))
print(classification_report(y_test, y_pred_accuracy))
# Out:
# 0.7559523809523809
# [[65 21]
#  [20 62]]
#               precision    recall  f1-score   support
#
#            0       0.76      0.76      0.76        86
#            1       0.75      0.76      0.75        82
#
#    micro avg       0.76      0.76      0.76       168
#    macro avg       0.76      0.76      0.76       168
# weighted avg       0.76      0.76      0.76       168
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\preprocessing\data.py:645: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   return self.partial_fit(X, y)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\base.py:467: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   return self.fit(X, y, **fit_params).transform(X)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\pipeline.py:331: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   Xt = transform.transform(Xt)

# %%
#Displaying the confusion matrix with the hyperparameters selected for optimising accuracy
fig, ax = plt.subplots(figsize=(2.5, 2.5))
ax.matshow(confmat_acc, cmap=plt.cm.Blues, alpha=0.3)
for i in range(confmat_acc.shape[0]):
    for j in range(confmat_acc.shape[1]):
        ax.text(x=j, y=i, s=confmat_acc[i, j], va='center', ha='center')

plt.xlabel('predicted label')
plt.ylabel('true label')

plt.tight_layout()
plt.show()

# %%
#Tuning hyperparameters, specifing a range of values for the GridSearch to select the optimal hyperparamater values
param_range = [0.001, 0.01, 0.1, 1.0, 10.0, 100.0, 1000.0]
param_grid = [{'clf__C': param_range,'clf__kernel': ['linear']},
              {'clf__C': param_range,'clf__gamma': param_range,
               'clf__kernel': ['rbf']}]

#Using GridSearch to optimise for F1
gs_svc_f1 = GridSearchCV(estimator=pipe_svc,
                  param_grid=param_grid,
                  scoring='f1',
                  cv=10,
                  n_jobs=1)

#Fitting Gridsearch to the training data
gs_svc_f1 = gs_svc_f1.fit(X_train, y_train)
print('--> Tuned Parameters Best Score: ',gs_svc_f1.best_score_)
print('--> Best Parameters: \n',gs_svc_f1.best_params_)
# Out:
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\preprocessing\data.py:645: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   return self.partial_fit(X, y)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\base.py:467: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   return self.fit(X, y, **fit_params).transform(X)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\pipeline.py:331: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   Xt = transform.transform(Xt)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\pipeline.py:331: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   Xt = transform.transform(Xt)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\preprocessing\data.py:645: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   return self.partial_fit(X, y)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\base.py:467: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   return self.fit(X, y, **fit_params).transform(X)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\pipeline.py:331: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   Xt = transform.transform(Xt)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\pipeline.py:331: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   Xt = transform.transform(Xt)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\preprocessing\data.py:645: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   return self.partial_fit(X, y)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\base.py:467: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   return self.fit(X, y, **fit_params).transform(X)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\pipeline.py:331: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   Xt = transform.transform(Xt)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\pipeline.py:331: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   Xt = transform.transform(Xt)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\preprocessing\data.py:645: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   return self.partial_fit(X, y)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\base.py:467: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   return self.fit(X, y, **fit_params).transform(X)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\pipeline.py:331: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   Xt = transform.transform(Xt)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\pipeline.py:331: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   Xt = transform.transform(Xt)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\preprocessing\data.py:645: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   return self.partial_fit(X, y)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\base.py:467: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   return self.fit(X, y, **fit_params).transform(X)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\pipeline.py:331: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   Xt = transform.transform(Xt)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\pipeline.py:331: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   Xt = transform.transform(Xt)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\preprocessing\data.py:645: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   return self.partial_fit(X, y)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\base.py:467: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   return self.fit(X, y, **fit_params).transform(X)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\pipeline.py:331: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   Xt = transform.transform(Xt)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\pipeline.py:331: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   Xt = transform.transform(Xt)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\preprocessing\data.py:645: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   return self.partial_fit(X, y)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\base.py:467: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   return self.fit(X, y, **fit_params).transform(X)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\pipeline.py:331: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   Xt = transform.transform(Xt)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\pipeline.py:331: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   Xt = transform.transform(Xt)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\preprocessing\data.py:645: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   return self.partial_fit(X, y)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\base.py:467: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   return self.fit(X, y, **fit_params).transform(X)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\pipeline.py:331: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   Xt = transform.transform(Xt)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\pipeline.py:331: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   Xt = transform.transform(Xt)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\preprocessing\data.py:645: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   return self.partial_fit(X, y)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\base.py:467: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   return self.fit(X, y, **fit_params).transform(X)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\pipeline.py:331: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   Xt = transform.transform(Xt)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\pipeline.py:331: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   Xt = transform.transform(Xt)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\preprocessing\data.py:645: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   return self.partial_fit(X, y)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\base.py:467: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   return self.fit(X, y, **fit_params).transform(X)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\pipeline.py:331: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   Xt = transform.transform(Xt)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\pipeline.py:331: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   Xt = transform.transform(Xt)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\preprocessing\data.py:645: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   return self.partial_fit(X, y)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\base.py:467: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   return self.fit(X, y, **fit_params).transform(X)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\pipeline.py:331: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   Xt = transform.transform(Xt)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\pipeline.py:331: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   Xt = transform.transform(Xt)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\preprocessing\data.py:645: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   return self.partial_fit(X, y)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\base.py:467: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   return self.fit(X, y, **fit_params).transform(X)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\pipeline.py:331: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   Xt = transform.transform(Xt)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\pipeline.py:331: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   Xt = transform.transform(Xt)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\preprocessing\data.py:645: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   return self.partial_fit(X, y)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\base.py:467: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   return self.fit(X, y, **fit_params).transform(X)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\pipeline.py:331: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   Xt = transform.transform(Xt)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\pipeline.py:331: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   Xt = transform.transform(Xt)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\preprocessing\data.py:645: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   return self.partial_fit(X, y)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\base.py:467: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   return self.fit(X, y, **fit_params).transform(X)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\pipeline.py:331: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   Xt = transform.transform(Xt)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\pipeline.py:331: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   Xt = transform.transform(Xt)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\preprocessing\data.py:645: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   return self.partial_fit(X, y)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\base.py:467: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   return self.fit(X, y, **fit_params).transform(X)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\pipeline.py:331: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   Xt = transform.transform(Xt)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\pipeline.py:331: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   Xt = transform.transform(Xt)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\preprocessing\data.py:645: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   return self.partial_fit(X, y)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\base.py:467: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   return self.fit(X, y, **fit_params).transform(X)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\pipeline.py:331: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   Xt = transform.transform(Xt)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\pipeline.py:331: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   Xt = transform.transform(Xt)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\preprocessing\data.py:645: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   return self.partial_fit(X, y)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\base.py:467: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   return self.fit(X, y, **fit_params).transform(X)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\pipeline.py:331: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   Xt = transform.transform(Xt)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\pipeline.py:331: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   Xt = transform.transform(Xt)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\preprocessing\data.py:645: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   return self.partial_fit(X, y)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\base.py:467: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   return self.fit(X, y, **fit_params).transform(X)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\pipeline.py:331: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   Xt = transform.transform(Xt)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\pipeline.py:331: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   Xt = transform.transform(Xt)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\preprocessing\data.py:645: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   return self.partial_fit(X, y)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\base.py:467: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   return self.fit(X, y, **fit_params).transform(X)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\pipeline.py:331: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   Xt = transform.transform(Xt)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\pipeline.py:331: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   Xt = transform.transform(Xt)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\preprocessing\data.py:645: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   return self.partial_fit(X, y)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\base.py:467: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   return self.fit(X, y, **fit_params).transform(X)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\pipeline.py:331: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   Xt = transform.transform(Xt)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\pipeline.py:331: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   Xt = transform.transform(Xt)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\preprocessing\data.py:645: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   return self.partial_fit(X, y)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\base.py:467: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   return self.fit(X, y, **fit_params).transform(X)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\pipeline.py:331: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   Xt = transform.transform(Xt)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\pipeline.py:331: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   Xt = transform.transform(Xt)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\preprocessing\data.py:645: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   return self.partial_fit(X, y)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\base.py:467: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   return self.fit(X, y, **fit_params).transform(X)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\pipeline.py:331: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   Xt = transform.transform(Xt)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\pipeline.py:331: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   Xt = transform.transform(Xt)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\preprocessing\data.py:645: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   return self.partial_fit(X, y)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\base.py:467: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   return self.fit(X, y, **fit_params).transform(X)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\pipeline.py:331: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   Xt = transform.transform(Xt)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\pipeline.py:331: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   Xt = transform.transform(Xt)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\preprocessing\data.py:645: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   return self.partial_fit(X, y)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\base.py:467: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   return self.fit(X, y, **fit_params).transform(X)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\pipeline.py:331: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   Xt = transform.transform(Xt)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\pipeline.py:331: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   Xt = transform.transform(Xt)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\preprocessing\data.py:645: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   return self.partial_fit(X, y)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\base.py:467: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   return self.fit(X, y, **fit_params).transform(X)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\pipeline.py:331: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   Xt = transform.transform(Xt)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\pipeline.py:331: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   Xt = transform.transform(Xt)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\preprocessing\data.py:645: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   return self.partial_fit(X, y)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\base.py:467: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   return self.fit(X, y, **fit_params).transform(X)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\pipeline.py:331: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   Xt = transform.transform(Xt)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\pipeline.py:331: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   Xt = transform.transform(Xt)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\preprocessing\data.py:645: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   return self.partial_fit(X, y)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\base.py:467: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   return self.fit(X, y, **fit_params).transform(X)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\pipeline.py:331: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   Xt = transform.transform(Xt)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\pipeline.py:331: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   Xt = transform.transform(Xt)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\preprocessing\data.py:645: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   return self.partial_fit(X, y)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\base.py:467: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   return self.fit(X, y, **fit_params).transform(X)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\pipeline.py:331: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   Xt = transform.transform(Xt)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\pipeline.py:331: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   Xt = transform.transform(Xt)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\preprocessing\data.py:645: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   return self.partial_fit(X, y)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\base.py:467: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   return self.fit(X, y, **fit_params).transform(X)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\pipeline.py:331: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   Xt = transform.transform(Xt)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\pipeline.py:331: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   Xt = transform.transform(Xt)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\preprocessing\data.py:645: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   return self.partial_fit(X, y)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\base.py:467: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   return self.fit(X, y, **fit_params).transform(X)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\pipeline.py:331: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   Xt = transform.transform(Xt)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\pipeline.py:331: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   Xt = transform.transform(Xt)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\preprocessing\data.py:645: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   return self.partial_fit(X, y)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\base.py:467: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   return self.fit(X, y, **fit_params).transform(X)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\pipeline.py:331: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   Xt = transform.transform(Xt)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\pipeline.py:331: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   Xt = transform.transform(Xt)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\preprocessing\data.py:645: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   return self.partial_fit(X, y)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\base.py:467: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   return self.fit(X, y, **fit_params).transform(X)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\pipeline.py:331: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   Xt = transform.transform(Xt)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\pipeline.py:331: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   Xt = transform.transform(Xt)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\preprocessing\data.py:645: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   return self.partial_fit(X, y)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\base.py:467: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   return self.fit(X, y, **fit_params).transform(X)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\pipeline.py:331: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   Xt = transform.transform(Xt)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\pipeline.py:331: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   Xt = transform.transform(Xt)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\preprocessing\data.py:645: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   return self.partial_fit(X, y)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\base.py:467: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   return self.fit(X, y, **fit_params).transform(X)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\pipeline.py:331: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   Xt = transform.transform(Xt)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\pipeline.py:331: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   Xt = transform.transform(Xt)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\preprocessing\data.py:645: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   return self.partial_fit(X, y)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\base.py:467: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   return self.fit(X, y, **fit_params).transform(X)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\pipeline.py:331: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   Xt = transform.transform(Xt)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\pipeline.py:331: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   Xt = transform.transform(Xt)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\preprocessing\data.py:645: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   return self.partial_fit(X, y)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\base.py:467: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   return self.fit(X, y, **fit_params).transform(X)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\pipeline.py:331: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   Xt = transform.transform(Xt)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\pipeline.py:331: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   Xt = transform.transform(Xt)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\preprocessing\data.py:645: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   return self.partial_fit(X, y)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\base.py:467: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   return self.fit(X, y, **fit_params).transform(X)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\pipeline.py:331: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   Xt = transform.transform(Xt)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\pipeline.py:331: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   Xt = transform.transform(Xt)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\preprocessing\data.py:645: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   return self.partial_fit(X, y)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\base.py:467: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   return self.fit(X, y, **fit_params).transform(X)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\pipeline.py:331: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   Xt = transform.transform(Xt)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\pipeline.py:331: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   Xt = transform.transform(Xt)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\preprocessing\data.py:645: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   return self.partial_fit(X, y)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\base.py:467: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   return self.fit(X, y, **fit_params).transform(X)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\pipeline.py:331: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   Xt = transform.transform(Xt)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\pipeline.py:331: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   Xt = transform.transform(Xt)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\preprocessing\data.py:645: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   return self.partial_fit(X, y)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\base.py:467: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   return self.fit(X, y, **fit_params).transform(X)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\pipeline.py:331: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   Xt = transform.transform(Xt)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\pipeline.py:331: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   Xt = transform.transform(Xt)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\preprocessing\data.py:645: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   return self.partial_fit(X, y)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\base.py:467: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   return self.fit(X, y, **fit_params).transform(X)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\pipeline.py:331: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   Xt = transform.transform(Xt)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\pipeline.py:331: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   Xt = transform.transform(Xt)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\preprocessing\data.py:645: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   return self.partial_fit(X, y)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\base.py:467: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   return self.fit(X, y, **fit_params).transform(X)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\pipeline.py:331: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   Xt = transform.transform(Xt)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\pipeline.py:331: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   Xt = transform.transform(Xt)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\preprocessing\data.py:645: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   return self.partial_fit(X, y)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\base.py:467: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   return self.fit(X, y, **fit_params).transform(X)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\pipeline.py:331: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   Xt = transform.transform(Xt)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\pipeline.py:331: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   Xt = transform.transform(Xt)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\preprocessing\data.py:645: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   return self.partial_fit(X, y)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\base.py:467: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   return self.fit(X, y, **fit_params).transform(X)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\pipeline.py:331: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   Xt = transform.transform(Xt)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\pipeline.py:331: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   Xt = transform.transform(Xt)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\preprocessing\data.py:645: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   return self.partial_fit(X, y)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\base.py:467: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   return self.fit(X, y, **fit_params).transform(X)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\pipeline.py:331: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   Xt = transform.transform(Xt)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\pipeline.py:331: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   Xt = transform.transform(Xt)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\preprocessing\data.py:645: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   return self.partial_fit(X, y)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\base.py:467: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   return self.fit(X, y, **fit_params).transform(X)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\pipeline.py:331: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   Xt = transform.transform(Xt)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\pipeline.py:331: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   Xt = transform.transform(Xt)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\preprocessing\data.py:645: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   return self.partial_fit(X, y)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\base.py:467: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   return self.fit(X, y, **fit_params).transform(X)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\pipeline.py:331: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   Xt = transform.transform(Xt)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\pipeline.py:331: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   Xt = transform.transform(Xt)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\preprocessing\data.py:645: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   return self.partial_fit(X, y)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\base.py:467: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   return self.fit(X, y, **fit_params).transform(X)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\pipeline.py:331: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   Xt = transform.transform(Xt)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\pipeline.py:331: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   Xt = transform.transform(Xt)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\preprocessing\data.py:645: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   return self.partial_fit(X, y)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\base.py:467: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   return self.fit(X, y, **fit_params).transform(X)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\pipeline.py:331: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   Xt = transform.transform(Xt)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\pipeline.py:331: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   Xt = transform.transform(Xt)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\preprocessing\data.py:645: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   return self.partial_fit(X, y)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\base.py:467: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   return self.fit(X, y, **fit_params).transform(X)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\pipeline.py:331: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   Xt = transform.transform(Xt)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\pipeline.py:331: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   Xt = transform.transform(Xt)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\preprocessing\data.py:645: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   return self.partial_fit(X, y)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\base.py:467: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   return self.fit(X, y, **fit_params).transform(X)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\pipeline.py:331: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   Xt = transform.transform(Xt)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\pipeline.py:331: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   Xt = transform.transform(Xt)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\preprocessing\data.py:645: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   return self.partial_fit(X, y)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\base.py:467: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   return self.fit(X, y, **fit_params).transform(X)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\pipeline.py:331: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   Xt = transform.transform(Xt)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\pipeline.py:331: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   Xt = transform.transform(Xt)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\preprocessing\data.py:645: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   return self.partial_fit(X, y)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\base.py:467: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   return self.fit(X, y, **fit_params).transform(X)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\pipeline.py:331: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   Xt = transform.transform(Xt)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\pipeline.py:331: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   Xt = transform.transform(Xt)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\preprocessing\data.py:645: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   return self.partial_fit(X, y)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\base.py:467: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   return self.fit(X, y, **fit_params).transform(X)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\pipeline.py:331: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   Xt = transform.transform(Xt)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\pipeline.py:331: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   Xt = transform.transform(Xt)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\preprocessing\data.py:645: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   return self.partial_fit(X, y)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\base.py:467: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   return self.fit(X, y, **fit_params).transform(X)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\pipeline.py:331: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   Xt = transform.transform(Xt)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\pipeline.py:331: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   Xt = transform.transform(Xt)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\preprocessing\data.py:645: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   return self.partial_fit(X, y)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\base.py:467: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   return self.fit(X, y, **fit_params).transform(X)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\pipeline.py:331: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   Xt = transform.transform(Xt)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\pipeline.py:331: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   Xt = transform.transform(Xt)
# ...
#   return self.fit(X, y, **fit_params).transform(X)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\pipeline.py:331: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   Xt = transform.transform(Xt)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\pipeline.py:331: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   Xt = transform.transform(Xt)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\preprocessing\data.py:645: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   return self.partial_fit(X, y)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\base.py:467: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   return self.fit(X, y, **fit_params).transform(X)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\pipeline.py:331: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   Xt = transform.transform(Xt)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\pipeline.py:331: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   Xt = transform.transform(Xt)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\preprocessing\data.py:645: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   return self.partial_fit(X, y)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\base.py:467: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   return self.fit(X, y, **fit_params).transform(X)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\pipeline.py:331: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   Xt = transform.transform(Xt)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\pipeline.py:331: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   Xt = transform.transform(Xt)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\preprocessing\data.py:645: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   return self.partial_fit(X, y)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\base.py:467: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   return self.fit(X, y, **fit_params).transform(X)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\pipeline.py:331: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   Xt = transform.transform(Xt)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\pipeline.py:331: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   Xt = transform.transform(Xt)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\preprocessing\data.py:645: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   return self.partial_fit(X, y)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\base.py:467: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   return self.fit(X, y, **fit_params).transform(X)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\pipeline.py:331: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   Xt = transform.transform(Xt)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\pipeline.py:331: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   Xt = transform.transform(Xt)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\preprocessing\data.py:645: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   return self.partial_fit(X, y)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\base.py:467: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   return self.fit(X, y, **fit_params).transform(X)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\pipeline.py:331: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   Xt = transform.transform(Xt)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\pipeline.py:331: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   Xt = transform.transform(Xt)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\preprocessing\data.py:645: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   return self.partial_fit(X, y)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\base.py:467: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   return self.fit(X, y, **fit_params).transform(X)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\pipeline.py:331: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   Xt = transform.transform(Xt)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\pipeline.py:331: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   Xt = transform.transform(Xt)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\preprocessing\data.py:645: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   return self.partial_fit(X, y)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\base.py:467: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   return self.fit(X, y, **fit_params).transform(X)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\pipeline.py:331: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   Xt = transform.transform(Xt)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\pipeline.py:331: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   Xt = transform.transform(Xt)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\preprocessing\data.py:645: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   return self.partial_fit(X, y)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\base.py:467: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   return self.fit(X, y, **fit_params).transform(X)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\pipeline.py:331: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   Xt = transform.transform(Xt)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\pipeline.py:331: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   Xt = transform.transform(Xt)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\preprocessing\data.py:645: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   return self.partial_fit(X, y)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\base.py:467: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   return self.fit(X, y, **fit_params).transform(X)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\pipeline.py:331: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   Xt = transform.transform(Xt)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\pipeline.py:331: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   Xt = transform.transform(Xt)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\preprocessing\data.py:645: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   return self.partial_fit(X, y)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\base.py:467: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   return self.fit(X, y, **fit_params).transform(X)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\pipeline.py:331: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   Xt = transform.transform(Xt)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\pipeline.py:331: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   Xt = transform.transform(Xt)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\preprocessing\data.py:645: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   return self.partial_fit(X, y)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\base.py:467: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   return self.fit(X, y, **fit_params).transform(X)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\pipeline.py:331: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   Xt = transform.transform(Xt)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\pipeline.py:331: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   Xt = transform.transform(Xt)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\preprocessing\data.py:645: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   return self.partial_fit(X, y)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\base.py:467: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   return self.fit(X, y, **fit_params).transform(X)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\pipeline.py:331: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   Xt = transform.transform(Xt)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\pipeline.py:331: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   Xt = transform.transform(Xt)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\preprocessing\data.py:645: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   return self.partial_fit(X, y)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\base.py:467: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   return self.fit(X, y, **fit_params).transform(X)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\pipeline.py:331: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   Xt = transform.transform(Xt)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\pipeline.py:331: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   Xt = transform.transform(Xt)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\preprocessing\data.py:645: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   return self.partial_fit(X, y)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\base.py:467: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   return self.fit(X, y, **fit_params).transform(X)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\pipeline.py:331: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   Xt = transform.transform(Xt)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\pipeline.py:331: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   Xt = transform.transform(Xt)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\preprocessing\data.py:645: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   return self.partial_fit(X, y)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\base.py:467: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   return self.fit(X, y, **fit_params).transform(X)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\pipeline.py:331: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   Xt = transform.transform(Xt)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\pipeline.py:331: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   Xt = transform.transform(Xt)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\preprocessing\data.py:645: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   return self.partial_fit(X, y)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\base.py:467: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   return self.fit(X, y, **fit_params).transform(X)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\pipeline.py:331: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   Xt = transform.transform(Xt)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\pipeline.py:331: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   Xt = transform.transform(Xt)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\preprocessing\data.py:645: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   return self.partial_fit(X, y)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\base.py:467: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   return self.fit(X, y, **fit_params).transform(X)
# --> Tuned Parameters Best Score:  0.8346268420300521
# --> Best Parameters:
#  {'clf__C': 0.001, 'clf__kernel': 'linear'}
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\pipeline.py:331: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   Xt = transform.transform(Xt)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\pipeline.py:331: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   Xt = transform.transform(Xt)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\model_selection\_search.py:841: DeprecationWarning: The default of the `iid` parameter will change from True to False in version 0.22 and will be removed in 0.24. This will change numeric results when test-set sizes are unequal.
#   DeprecationWarning)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\preprocessing\data.py:645: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   return self.partial_fit(X, y)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\base.py:467: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   return self.fit(X, y, **fit_params).transform(X)

# %%
#Use best parameters
clf_svc_f1= gs_svc_f1.best_estimator_

#Get Final Scores
clf_svc_f1.fit(X_train, y_train)
scores = cross_val_score(estimator=clf_svc_f1,
                         X=X_train,
                         y=y_train,
                         cv=10,
                         n_jobs=1)
print('--> Final Model Training F1 score: %.3f +/- %.3f' %(np.mean(scores), np.std(scores)))

print('--> Final F1 score on Test set: %.5f' % clf_svc_f1.score(X_test,y_test))
# Out:
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\preprocessing\data.py:645: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   return self.partial_fit(X, y)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\base.py:467: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   return self.fit(X, y, **fit_params).transform(X)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\preprocessing\data.py:645: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   return self.partial_fit(X, y)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\base.py:467: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   return self.fit(X, y, **fit_params).transform(X)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\pipeline.py:511: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   Xt = transform.transform(Xt)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\preprocessing\data.py:645: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   return self.partial_fit(X, y)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\base.py:467: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   return self.fit(X, y, **fit_params).transform(X)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\pipeline.py:511: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   Xt = transform.transform(Xt)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\preprocessing\data.py:645: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   return self.partial_fit(X, y)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\base.py:467: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   return self.fit(X, y, **fit_params).transform(X)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\pipeline.py:511: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   Xt = transform.transform(Xt)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\preprocessing\data.py:645: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   return self.partial_fit(X, y)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\base.py:467: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   return self.fit(X, y, **fit_params).transform(X)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\pipeline.py:511: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   Xt = transform.transform(Xt)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\preprocessing\data.py:645: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   return self.partial_fit(X, y)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\base.py:467: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   return self.fit(X, y, **fit_params).transform(X)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\pipeline.py:511: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   Xt = transform.transform(Xt)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\preprocessing\data.py:645: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   return self.partial_fit(X, y)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\base.py:467: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   return self.fit(X, y, **fit_params).transform(X)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\pipeline.py:511: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   Xt = transform.transform(Xt)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\preprocessing\data.py:645: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   return self.partial_fit(X, y)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\base.py:467: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   return self.fit(X, y, **fit_params).transform(X)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\pipeline.py:511: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   Xt = transform.transform(Xt)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\preprocessing\data.py:645: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   return self.partial_fit(X, y)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\base.py:467: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   return self.fit(X, y, **fit_params).transform(X)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\pipeline.py:511: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   Xt = transform.transform(Xt)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\preprocessing\data.py:645: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   return self.partial_fit(X, y)
# --> Final Model Training F1 score: 0.823 +/- 0.035
# --> Final F1 score on Test set: 0.75595
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\base.py:467: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   return self.fit(X, y, **fit_params).transform(X)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\pipeline.py:511: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   Xt = transform.transform(Xt)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\preprocessing\data.py:645: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   return self.partial_fit(X, y)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\base.py:467: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   return self.fit(X, y, **fit_params).transform(X)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\pipeline.py:511: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   Xt = transform.transform(Xt)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\pipeline.py:511: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   Xt = transform.transform(Xt)

# %%
clf_svc_f1.fit(X_train, y_train)
y_pred_f1 = clf_svc_f1.predict(X_test)
confmat_f1= confusion_matrix(y_true=y_test, y_pred=y_pred_f1)
print(accuracy_score(y_test, y_pred_f1))
print(confusion_matrix(y_test, y_pred_f1))
print(classification_report(y_test, y_pred_f1))
# Out:
# 0.75
# [[65 21]
#  [20 62]]
#               precision    recall  f1-score   support
#
#            0       0.74      0.79      0.76        86
#            1       0.76      0.71      0.73        82
#
#    micro avg       0.75      0.75      0.75       168
#    macro avg       0.75      0.75      0.75       168
# weighted avg       0.75      0.75      0.75       168
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\preprocessing\data.py:645: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   return self.partial_fit(X, y)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\base.py:467: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   return self.fit(X, y, **fit_params).transform(X)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\pipeline.py:331: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   Xt = transform.transform(Xt)

# %%
#Displaying the confusion matrix with the hyperparameters selected for optimising accuracy
fig, ax = plt.subplots(figsize=(2.5, 2.5))
ax.matshow(confmat_f1, cmap=plt.cm.Blues, alpha=0.3)
for i in range(confmat_f1.shape[0]):
    for j in range(confmat_f1.shape[1]):
        ax.text(x=j, y=i, s=confmat_f1[i, j], va='center', ha='center')

plt.xlabel('predicted label')
plt.ylabel('true label')

plt.tight_layout()
plt.show()

# %%
#Tuning hyperparameters, specifing a range of values for the GridSearch to select the optimal hyperparamater values
param_range = [0.001, 0.01, 0.1, 1.0, 10.0, 100.0, 1000.0]
param_grid = [{'clf__C': param_range,'clf__kernel': ['linear']},
              {'clf__C': param_range,'clf__gamma': param_range,
               'clf__kernel': ['rbf']}]

#Using GridSearch to optimise for Accuracy
gs_svc_precision = GridSearchCV(estimator=pipe_svc,
                  param_grid=param_grid,
                  scoring='precision',
                  cv=10,
                  n_jobs=1)

#Fitting Gridsearch to the training data
gs_svc_precision = gs_svc_precision.fit(X_train, y_train)
print('--> Tuned Parameters Best Score: ',gs_svc_precision.best_score_)
print('--> Best Parameters: \n',gs_svc_precision.best_params_)
# Out:
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\preprocessing\data.py:645: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   return self.partial_fit(X, y)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\base.py:467: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   return self.fit(X, y, **fit_params).transform(X)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\pipeline.py:331: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   Xt = transform.transform(Xt)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\pipeline.py:331: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   Xt = transform.transform(Xt)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\preprocessing\data.py:645: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   return self.partial_fit(X, y)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\base.py:467: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   return self.fit(X, y, **fit_params).transform(X)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\pipeline.py:331: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   Xt = transform.transform(Xt)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\pipeline.py:331: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   Xt = transform.transform(Xt)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\preprocessing\data.py:645: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   return self.partial_fit(X, y)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\base.py:467: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   return self.fit(X, y, **fit_params).transform(X)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\pipeline.py:331: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   Xt = transform.transform(Xt)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\pipeline.py:331: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   Xt = transform.transform(Xt)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\preprocessing\data.py:645: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   return self.partial_fit(X, y)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\base.py:467: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   return self.fit(X, y, **fit_params).transform(X)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\pipeline.py:331: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   Xt = transform.transform(Xt)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\pipeline.py:331: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   Xt = transform.transform(Xt)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\preprocessing\data.py:645: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   return self.partial_fit(X, y)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\base.py:467: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   return self.fit(X, y, **fit_params).transform(X)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\pipeline.py:331: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   Xt = transform.transform(Xt)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\pipeline.py:331: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   Xt = transform.transform(Xt)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\preprocessing\data.py:645: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   return self.partial_fit(X, y)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\base.py:467: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   return self.fit(X, y, **fit_params).transform(X)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\pipeline.py:331: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   Xt = transform.transform(Xt)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\pipeline.py:331: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   Xt = transform.transform(Xt)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\preprocessing\data.py:645: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   return self.partial_fit(X, y)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\base.py:467: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   return self.fit(X, y, **fit_params).transform(X)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\pipeline.py:331: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   Xt = transform.transform(Xt)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\pipeline.py:331: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   Xt = transform.transform(Xt)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\preprocessing\data.py:645: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   return self.partial_fit(X, y)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\base.py:467: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   return self.fit(X, y, **fit_params).transform(X)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\pipeline.py:331: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   Xt = transform.transform(Xt)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\pipeline.py:331: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   Xt = transform.transform(Xt)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\preprocessing\data.py:645: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   return self.partial_fit(X, y)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\base.py:467: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   return self.fit(X, y, **fit_params).transform(X)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\pipeline.py:331: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   Xt = transform.transform(Xt)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\pipeline.py:331: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   Xt = transform.transform(Xt)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\preprocessing\data.py:645: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   return self.partial_fit(X, y)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\base.py:467: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   return self.fit(X, y, **fit_params).transform(X)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\pipeline.py:331: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   Xt = transform.transform(Xt)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\pipeline.py:331: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   Xt = transform.transform(Xt)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\preprocessing\data.py:645: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   return self.partial_fit(X, y)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\base.py:467: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   return self.fit(X, y, **fit_params).transform(X)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\pipeline.py:331: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   Xt = transform.transform(Xt)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\pipeline.py:331: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   Xt = transform.transform(Xt)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\preprocessing\data.py:645: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   return self.partial_fit(X, y)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\base.py:467: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   return self.fit(X, y, **fit_params).transform(X)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\pipeline.py:331: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   Xt = transform.transform(Xt)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\pipeline.py:331: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   Xt = transform.transform(Xt)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\preprocessing\data.py:645: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   return self.partial_fit(X, y)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\base.py:467: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   return self.fit(X, y, **fit_params).transform(X)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\pipeline.py:331: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   Xt = transform.transform(Xt)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\pipeline.py:331: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   Xt = transform.transform(Xt)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\preprocessing\data.py:645: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   return self.partial_fit(X, y)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\base.py:467: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   return self.fit(X, y, **fit_params).transform(X)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\pipeline.py:331: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   Xt = transform.transform(Xt)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\pipeline.py:331: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   Xt = transform.transform(Xt)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\preprocessing\data.py:645: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   return self.partial_fit(X, y)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\base.py:467: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   return self.fit(X, y, **fit_params).transform(X)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\pipeline.py:331: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   Xt = transform.transform(Xt)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\pipeline.py:331: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   Xt = transform.transform(Xt)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\preprocessing\data.py:645: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   return self.partial_fit(X, y)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\base.py:467: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   return self.fit(X, y, **fit_params).transform(X)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\pipeline.py:331: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   Xt = transform.transform(Xt)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\pipeline.py:331: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   Xt = transform.transform(Xt)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\preprocessing\data.py:645: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   return self.partial_fit(X, y)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\base.py:467: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   return self.fit(X, y, **fit_params).transform(X)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\pipeline.py:331: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   Xt = transform.transform(Xt)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\pipeline.py:331: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   Xt = transform.transform(Xt)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\preprocessing\data.py:645: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   return self.partial_fit(X, y)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\base.py:467: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   return self.fit(X, y, **fit_params).transform(X)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\pipeline.py:331: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   Xt = transform.transform(Xt)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\pipeline.py:331: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   Xt = transform.transform(Xt)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\preprocessing\data.py:645: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   return self.partial_fit(X, y)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\base.py:467: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   return self.fit(X, y, **fit_params).transform(X)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\pipeline.py:331: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   Xt = transform.transform(Xt)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\pipeline.py:331: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   Xt = transform.transform(Xt)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\preprocessing\data.py:645: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   return self.partial_fit(X, y)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\base.py:467: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   return self.fit(X, y, **fit_params).transform(X)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\pipeline.py:331: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   Xt = transform.transform(Xt)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\pipeline.py:331: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   Xt = transform.transform(Xt)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\preprocessing\data.py:645: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   return self.partial_fit(X, y)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\base.py:467: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   return self.fit(X, y, **fit_params).transform(X)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\pipeline.py:331: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   Xt = transform.transform(Xt)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\pipeline.py:331: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   Xt = transform.transform(Xt)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\preprocessing\data.py:645: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   return self.partial_fit(X, y)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\base.py:467: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   return self.fit(X, y, **fit_params).transform(X)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\pipeline.py:331: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   Xt = transform.transform(Xt)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\pipeline.py:331: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   Xt = transform.transform(Xt)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\preprocessing\data.py:645: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   return self.partial_fit(X, y)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\base.py:467: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   return self.fit(X, y, **fit_params).transform(X)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\pipeline.py:331: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   Xt = transform.transform(Xt)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\pipeline.py:331: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   Xt = transform.transform(Xt)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\preprocessing\data.py:645: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   return self.partial_fit(X, y)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\base.py:467: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   return self.fit(X, y, **fit_params).transform(X)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\pipeline.py:331: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   Xt = transform.transform(Xt)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\pipeline.py:331: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   Xt = transform.transform(Xt)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\preprocessing\data.py:645: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   return self.partial_fit(X, y)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\base.py:467: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   return self.fit(X, y, **fit_params).transform(X)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\pipeline.py:331: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   Xt = transform.transform(Xt)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\pipeline.py:331: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   Xt = transform.transform(Xt)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\preprocessing\data.py:645: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   return self.partial_fit(X, y)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\base.py:467: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   return self.fit(X, y, **fit_params).transform(X)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\pipeline.py:331: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   Xt = transform.transform(Xt)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\pipeline.py:331: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   Xt = transform.transform(Xt)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\preprocessing\data.py:645: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   return self.partial_fit(X, y)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\base.py:467: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   return self.fit(X, y, **fit_params).transform(X)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\pipeline.py:331: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   Xt = transform.transform(Xt)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\pipeline.py:331: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   Xt = transform.transform(Xt)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\preprocessing\data.py:645: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   return self.partial_fit(X, y)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\base.py:467: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   return self.fit(X, y, **fit_params).transform(X)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\pipeline.py:331: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   Xt = transform.transform(Xt)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\pipeline.py:331: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   Xt = transform.transform(Xt)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\preprocessing\data.py:645: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   return self.partial_fit(X, y)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\base.py:467: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   return self.fit(X, y, **fit_params).transform(X)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\pipeline.py:331: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   Xt = transform.transform(Xt)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\pipeline.py:331: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   Xt = transform.transform(Xt)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\preprocessing\data.py:645: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   return self.partial_fit(X, y)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\base.py:467: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   return self.fit(X, y, **fit_params).transform(X)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\pipeline.py:331: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   Xt = transform.transform(Xt)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\pipeline.py:331: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   Xt = transform.transform(Xt)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\preprocessing\data.py:645: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   return self.partial_fit(X, y)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\base.py:467: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   return self.fit(X, y, **fit_params).transform(X)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\pipeline.py:331: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   Xt = transform.transform(Xt)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\pipeline.py:331: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   Xt = transform.transform(Xt)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\preprocessing\data.py:645: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   return self.partial_fit(X, y)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\base.py:467: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   return self.fit(X, y, **fit_params).transform(X)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\pipeline.py:331: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   Xt = transform.transform(Xt)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\pipeline.py:331: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   Xt = transform.transform(Xt)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\preprocessing\data.py:645: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   return self.partial_fit(X, y)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\base.py:467: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   return self.fit(X, y, **fit_params).transform(X)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\pipeline.py:331: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   Xt = transform.transform(Xt)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\pipeline.py:331: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   Xt = transform.transform(Xt)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\preprocessing\data.py:645: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   return self.partial_fit(X, y)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\base.py:467: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   return self.fit(X, y, **fit_params).transform(X)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\pipeline.py:331: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   Xt = transform.transform(Xt)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\pipeline.py:331: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   Xt = transform.transform(Xt)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\preprocessing\data.py:645: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   return self.partial_fit(X, y)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\base.py:467: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   return self.fit(X, y, **fit_params).transform(X)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\pipeline.py:331: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   Xt = transform.transform(Xt)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\pipeline.py:331: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   Xt = transform.transform(Xt)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\preprocessing\data.py:645: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   return self.partial_fit(X, y)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\base.py:467: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   return self.fit(X, y, **fit_params).transform(X)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\pipeline.py:331: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   Xt = transform.transform(Xt)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\pipeline.py:331: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   Xt = transform.transform(Xt)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\preprocessing\data.py:645: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   return self.partial_fit(X, y)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\base.py:467: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   return self.fit(X, y, **fit_params).transform(X)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\pipeline.py:331: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   Xt = transform.transform(Xt)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\pipeline.py:331: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   Xt = transform.transform(Xt)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\preprocessing\data.py:645: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   return self.partial_fit(X, y)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\base.py:467: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   return self.fit(X, y, **fit_params).transform(X)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\pipeline.py:331: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   Xt = transform.transform(Xt)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\pipeline.py:331: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   Xt = transform.transform(Xt)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\preprocessing\data.py:645: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   return self.partial_fit(X, y)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\base.py:467: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   return self.fit(X, y, **fit_params).transform(X)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\pipeline.py:331: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   Xt = transform.transform(Xt)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\pipeline.py:331: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   Xt = transform.transform(Xt)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\preprocessing\data.py:645: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   return self.partial_fit(X, y)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\base.py:467: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   return self.fit(X, y, **fit_params).transform(X)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\pipeline.py:331: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   Xt = transform.transform(Xt)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\pipeline.py:331: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   Xt = transform.transform(Xt)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\preprocessing\data.py:645: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   return self.partial_fit(X, y)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\base.py:467: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   return self.fit(X, y, **fit_params).transform(X)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\pipeline.py:331: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   Xt = transform.transform(Xt)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\pipeline.py:331: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   Xt = transform.transform(Xt)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\preprocessing\data.py:645: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   return self.partial_fit(X, y)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\base.py:467: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   return self.fit(X, y, **fit_params).transform(X)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\pipeline.py:331: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   Xt = transform.transform(Xt)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\pipeline.py:331: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   Xt = transform.transform(Xt)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\preprocessing\data.py:645: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   return self.partial_fit(X, y)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\base.py:467: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   return self.fit(X, y, **fit_params).transform(X)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\pipeline.py:331: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   Xt = transform.transform(Xt)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\pipeline.py:331: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   Xt = transform.transform(Xt)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\preprocessing\data.py:645: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   return self.partial_fit(X, y)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\base.py:467: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   return self.fit(X, y, **fit_params).transform(X)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\pipeline.py:331: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   Xt = transform.transform(Xt)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\pipeline.py:331: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   Xt = transform.transform(Xt)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\preprocessing\data.py:645: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   return self.partial_fit(X, y)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\base.py:467: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   return self.fit(X, y, **fit_params).transform(X)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\pipeline.py:331: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   Xt = transform.transform(Xt)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\pipeline.py:331: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   Xt = transform.transform(Xt)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\preprocessing\data.py:645: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   return self.partial_fit(X, y)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\base.py:467: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   return self.fit(X, y, **fit_params).transform(X)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\pipeline.py:331: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   Xt = transform.transform(Xt)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\pipeline.py:331: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   Xt = transform.transform(Xt)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\preprocessing\data.py:645: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   return self.partial_fit(X, y)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\base.py:467: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   return self.fit(X, y, **fit_params).transform(X)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\pipeline.py:331: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   Xt = transform.transform(Xt)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\pipeline.py:331: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   Xt = transform.transform(Xt)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\preprocessing\data.py:645: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   return self.partial_fit(X, y)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\base.py:467: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   return self.fit(X, y, **fit_params).transform(X)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\pipeline.py:331: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   Xt = transform.transform(Xt)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\pipeline.py:331: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   Xt = transform.transform(Xt)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\preprocessing\data.py:645: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   return self.partial_fit(X, y)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\base.py:467: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   return self.fit(X, y, **fit_params).transform(X)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\pipeline.py:331: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   Xt = transform.transform(Xt)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\pipeline.py:331: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   Xt = transform.transform(Xt)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\preprocessing\data.py:645: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   return self.partial_fit(X, y)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\base.py:467: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   return self.fit(X, y, **fit_params).transform(X)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\pipeline.py:331: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   Xt = transform.transform(Xt)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\pipeline.py:331: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   Xt = transform.transform(Xt)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\preprocessing\data.py:645: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   return self.partial_fit(X, y)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\base.py:467: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   return self.fit(X, y, **fit_params).transform(X)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\pipeline.py:331: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   Xt = transform.transform(Xt)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\pipeline.py:331: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   Xt = transform.transform(Xt)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\preprocessing\data.py:645: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   return self.partial_fit(X, y)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\base.py:467: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   return self.fit(X, y, **fit_params).transform(X)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\pipeline.py:331: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   Xt = transform.transform(Xt)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\pipeline.py:331: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   Xt = transform.transform(Xt)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\preprocessing\data.py:645: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   return self.partial_fit(X, y)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\base.py:467: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   return self.fit(X, y, **fit_params).transform(X)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\pipeline.py:331: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   Xt = transform.transform(Xt)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\pipeline.py:331: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   Xt = transform.transform(Xt)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\preprocessing\data.py:645: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   return self.partial_fit(X, y)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\base.py:467: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   return self.fit(X, y, **fit_params).transform(X)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\pipeline.py:331: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   Xt = transform.transform(Xt)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\pipeline.py:331: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   Xt = transform.transform(Xt)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\preprocessing\data.py:645: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   return self.partial_fit(X, y)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\base.py:467: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   return self.fit(X, y, **fit_params).transform(X)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\pipeline.py:331: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   Xt = transform.transform(Xt)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\pipeline.py:331: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   Xt = transform.transform(Xt)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\preprocessing\data.py:645: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   return self.partial_fit(X, y)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\base.py:467: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   return self.fit(X, y, **fit_params).transform(X)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\pipeline.py:331: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   Xt = transform.transform(Xt)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\pipeline.py:331: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   Xt = transform.transform(Xt)
# ...
#   return self.fit(X, y, **fit_params).transform(X)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\pipeline.py:331: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   Xt = transform.transform(Xt)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\pipeline.py:331: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   Xt = transform.transform(Xt)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\preprocessing\data.py:645: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   return self.partial_fit(X, y)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\base.py:467: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   return self.fit(X, y, **fit_params).transform(X)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\pipeline.py:331: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   Xt = transform.transform(Xt)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\pipeline.py:331: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   Xt = transform.transform(Xt)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\preprocessing\data.py:645: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   return self.partial_fit(X, y)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\base.py:467: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   return self.fit(X, y, **fit_params).transform(X)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\pipeline.py:331: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   Xt = transform.transform(Xt)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\pipeline.py:331: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   Xt = transform.transform(Xt)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\preprocessing\data.py:645: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   return self.partial_fit(X, y)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\base.py:467: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   return self.fit(X, y, **fit_params).transform(X)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\pipeline.py:331: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   Xt = transform.transform(Xt)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\pipeline.py:331: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   Xt = transform.transform(Xt)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\preprocessing\data.py:645: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   return self.partial_fit(X, y)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\base.py:467: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   return self.fit(X, y, **fit_params).transform(X)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\pipeline.py:331: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   Xt = transform.transform(Xt)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\pipeline.py:331: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   Xt = transform.transform(Xt)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\preprocessing\data.py:645: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   return self.partial_fit(X, y)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\base.py:467: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   return self.fit(X, y, **fit_params).transform(X)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\pipeline.py:331: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   Xt = transform.transform(Xt)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\pipeline.py:331: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   Xt = transform.transform(Xt)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\preprocessing\data.py:645: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   return self.partial_fit(X, y)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\base.py:467: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   return self.fit(X, y, **fit_params).transform(X)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\pipeline.py:331: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   Xt = transform.transform(Xt)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\pipeline.py:331: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   Xt = transform.transform(Xt)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\preprocessing\data.py:645: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   return self.partial_fit(X, y)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\base.py:467: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   return self.fit(X, y, **fit_params).transform(X)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\pipeline.py:331: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   Xt = transform.transform(Xt)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\pipeline.py:331: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   Xt = transform.transform(Xt)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\preprocessing\data.py:645: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   return self.partial_fit(X, y)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\base.py:467: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   return self.fit(X, y, **fit_params).transform(X)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\pipeline.py:331: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   Xt = transform.transform(Xt)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\pipeline.py:331: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   Xt = transform.transform(Xt)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\preprocessing\data.py:645: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   return self.partial_fit(X, y)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\base.py:467: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   return self.fit(X, y, **fit_params).transform(X)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\pipeline.py:331: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   Xt = transform.transform(Xt)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\pipeline.py:331: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   Xt = transform.transform(Xt)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\preprocessing\data.py:645: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   return self.partial_fit(X, y)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\base.py:467: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   return self.fit(X, y, **fit_params).transform(X)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\pipeline.py:331: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   Xt = transform.transform(Xt)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\pipeline.py:331: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   Xt = transform.transform(Xt)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\preprocessing\data.py:645: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   return self.partial_fit(X, y)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\base.py:467: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   return self.fit(X, y, **fit_params).transform(X)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\pipeline.py:331: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   Xt = transform.transform(Xt)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\pipeline.py:331: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   Xt = transform.transform(Xt)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\preprocessing\data.py:645: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   return self.partial_fit(X, y)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\base.py:467: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   return self.fit(X, y, **fit_params).transform(X)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\pipeline.py:331: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   Xt = transform.transform(Xt)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\pipeline.py:331: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   Xt = transform.transform(Xt)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\preprocessing\data.py:645: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   return self.partial_fit(X, y)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\base.py:467: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   return self.fit(X, y, **fit_params).transform(X)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\pipeline.py:331: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   Xt = transform.transform(Xt)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\pipeline.py:331: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   Xt = transform.transform(Xt)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\preprocessing\data.py:645: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   return self.partial_fit(X, y)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\base.py:467: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   return self.fit(X, y, **fit_params).transform(X)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\pipeline.py:331: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   Xt = transform.transform(Xt)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\pipeline.py:331: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   Xt = transform.transform(Xt)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\preprocessing\data.py:645: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   return self.partial_fit(X, y)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\base.py:467: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   return self.fit(X, y, **fit_params).transform(X)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\pipeline.py:331: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   Xt = transform.transform(Xt)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\pipeline.py:331: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   Xt = transform.transform(Xt)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\preprocessing\data.py:645: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   return self.partial_fit(X, y)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\base.py:467: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   return self.fit(X, y, **fit_params).transform(X)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\pipeline.py:331: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   Xt = transform.transform(Xt)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\pipeline.py:331: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   Xt = transform.transform(Xt)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\preprocessing\data.py:645: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   return self.partial_fit(X, y)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\base.py:467: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   return self.fit(X, y, **fit_params).transform(X)
# --> Tuned Parameters Best Score:  0.7964148511486354
# --> Best Parameters:
#  {'clf__C': 0.01, 'clf__gamma': 1.0, 'clf__kernel': 'rbf'}
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\pipeline.py:331: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   Xt = transform.transform(Xt)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\pipeline.py:331: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   Xt = transform.transform(Xt)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\model_selection\_search.py:841: DeprecationWarning: The default of the `iid` parameter will change from True to False in version 0.22 and will be removed in 0.24. This will change numeric results when test-set sizes are unequal.
#   DeprecationWarning)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\preprocessing\data.py:645: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   return self.partial_fit(X, y)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\base.py:467: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   return self.fit(X, y, **fit_params).transform(X)

# %%
#Use best parameters
clf_svc_precision= gs_svc_precision.best_estimator_

#Get Final Scores
clf_svc_precision.fit(X_train, y_train)
scores = cross_val_score(estimator=clf_svc_precision,
                         X=X_train,
                         y=y_train,
                         cv=10,
                         n_jobs=1)
print('--> Final Model Training Precision score: %.3f +/- %.3f' %(np.mean(scores), np.std(scores)))

print('--> Final Precision score on Test set: %.5f' % clf_svc_precision.score(X_test,y_test))
# Out:
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\preprocessing\data.py:645: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   return self.partial_fit(X, y)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\base.py:467: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   return self.fit(X, y, **fit_params).transform(X)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\preprocessing\data.py:645: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   return self.partial_fit(X, y)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\base.py:467: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   return self.fit(X, y, **fit_params).transform(X)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\pipeline.py:511: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   Xt = transform.transform(Xt)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\preprocessing\data.py:645: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   return self.partial_fit(X, y)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\base.py:467: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   return self.fit(X, y, **fit_params).transform(X)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\pipeline.py:511: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   Xt = transform.transform(Xt)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\preprocessing\data.py:645: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   return self.partial_fit(X, y)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\base.py:467: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   return self.fit(X, y, **fit_params).transform(X)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\pipeline.py:511: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   Xt = transform.transform(Xt)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\preprocessing\data.py:645: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   return self.partial_fit(X, y)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\base.py:467: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   return self.fit(X, y, **fit_params).transform(X)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\pipeline.py:511: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   Xt = transform.transform(Xt)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\preprocessing\data.py:645: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   return self.partial_fit(X, y)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\base.py:467: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   return self.fit(X, y, **fit_params).transform(X)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\pipeline.py:511: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   Xt = transform.transform(Xt)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\preprocessing\data.py:645: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   return self.partial_fit(X, y)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\base.py:467: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   return self.fit(X, y, **fit_params).transform(X)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\pipeline.py:511: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   Xt = transform.transform(Xt)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\preprocessing\data.py:645: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   return self.partial_fit(X, y)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\base.py:467: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   return self.fit(X, y, **fit_params).transform(X)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\pipeline.py:511: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   Xt = transform.transform(Xt)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\preprocessing\data.py:645: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   return self.partial_fit(X, y)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\base.py:467: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   return self.fit(X, y, **fit_params).transform(X)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\pipeline.py:511: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   Xt = transform.transform(Xt)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\preprocessing\data.py:645: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   return self.partial_fit(X, y)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\base.py:467: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   return self.fit(X, y, **fit_params).transform(X)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\pipeline.py:511: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   Xt = transform.transform(Xt)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\preprocessing\data.py:645: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   return self.partial_fit(X, y)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\base.py:467: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   return self.fit(X, y, **fit_params).transform(X)
# --> Final Model Training Precision score: 0.798 +/- 0.051
# --> Final Precision score on Test set: 0.75000
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\pipeline.py:511: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   Xt = transform.transform(Xt)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\pipeline.py:511: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   Xt = transform.transform(Xt)

# %%
clf_svc_precision.fit(X_train, y_train)
y_pred_precision = clf_svc_precision.predict(X_test)
confmat_precision = confusion_matrix(y_true=y_test, y_pred=y_pred_precision)
print(accuracy_score(y_test, y_pred_precision))
print(confusion_matrix(y_test, y_pred_precision))
print(classification_report(y_test, y_pred_precision))
# Out:
# 0.75
# [[68 18]
#  [24 58]]
#               precision    recall  f1-score   support
#
#            0       0.74      0.79      0.76        86
#            1       0.76      0.71      0.73        82
#
#    micro avg       0.75      0.75      0.75       168
#    macro avg       0.75      0.75      0.75       168
# weighted avg       0.75      0.75      0.75       168
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\preprocessing\data.py:645: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   return self.partial_fit(X, y)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\base.py:467: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   return self.fit(X, y, **fit_params).transform(X)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\pipeline.py:331: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   Xt = transform.transform(Xt)

# %%
fig, ax = plt.subplots(figsize=(2.5, 2.5))
ax.matshow(confmat_precision, cmap=plt.cm.Blues, alpha=0.3)
for i in range(confmat_precision.shape[0]):
    for j in range(confmat_f1.shape[1]):
        ax.text(x=j, y=i, s=confmat_precision[i, j], va='center', ha='center')

plt.xlabel('predicted label')
plt.ylabel('true label')

plt.tight_layout()
plt.show()

# %%
#Tuning hyperparameters, specifing a range of values for the GridSearch to select the optimal hyperparamater values
param_range = [0.001, 0.01, 0.1, 1.0, 10.0, 100.0, 1000.0]
param_grid = [{'clf__C': param_range,'clf__kernel': ['linear']},
              {'clf__C': param_range,'clf__gamma': param_range,
               'clf__kernel': ['rbf']}]

#Using GridSearch to optimise for Accuracy
gs_svc_auc = GridSearchCV(estimator=pipe_svc,
                  param_grid=param_grid,
                  scoring='roc_auc',
                  cv=10,
                  n_jobs=1)

#Fitting Gridsearch to the training data
gs_svc_auc = gs_svc_auc.fit(X_train, y_train)
print('--> Tuned Parameters Best Score: ',gs_svc_auc.best_score_)
print('--> Best Parameters: \n',gs_svc_auc.best_params_)
# Out:
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\preprocessing\data.py:645: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   return self.partial_fit(X, y)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\base.py:467: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   return self.fit(X, y, **fit_params).transform(X)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\pipeline.py:401: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   Xt = transform.transform(Xt)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\pipeline.py:401: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   Xt = transform.transform(Xt)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\preprocessing\data.py:645: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   return self.partial_fit(X, y)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\base.py:467: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   return self.fit(X, y, **fit_params).transform(X)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\pipeline.py:401: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   Xt = transform.transform(Xt)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\pipeline.py:401: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   Xt = transform.transform(Xt)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\preprocessing\data.py:645: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   return self.partial_fit(X, y)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\base.py:467: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   return self.fit(X, y, **fit_params).transform(X)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\pipeline.py:401: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   Xt = transform.transform(Xt)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\pipeline.py:401: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   Xt = transform.transform(Xt)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\preprocessing\data.py:645: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   return self.partial_fit(X, y)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\base.py:467: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   return self.fit(X, y, **fit_params).transform(X)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\pipeline.py:401: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   Xt = transform.transform(Xt)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\pipeline.py:401: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   Xt = transform.transform(Xt)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\preprocessing\data.py:645: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   return self.partial_fit(X, y)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\base.py:467: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   return self.fit(X, y, **fit_params).transform(X)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\pipeline.py:401: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   Xt = transform.transform(Xt)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\pipeline.py:401: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   Xt = transform.transform(Xt)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\preprocessing\data.py:645: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   return self.partial_fit(X, y)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\base.py:467: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   return self.fit(X, y, **fit_params).transform(X)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\pipeline.py:401: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   Xt = transform.transform(Xt)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\pipeline.py:401: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   Xt = transform.transform(Xt)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\preprocessing\data.py:645: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   return self.partial_fit(X, y)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\base.py:467: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   return self.fit(X, y, **fit_params).transform(X)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\pipeline.py:401: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   Xt = transform.transform(Xt)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\pipeline.py:401: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   Xt = transform.transform(Xt)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\preprocessing\data.py:645: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   return self.partial_fit(X, y)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\base.py:467: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   return self.fit(X, y, **fit_params).transform(X)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\pipeline.py:401: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   Xt = transform.transform(Xt)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\pipeline.py:401: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   Xt = transform.transform(Xt)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\preprocessing\data.py:645: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   return self.partial_fit(X, y)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\base.py:467: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   return self.fit(X, y, **fit_params).transform(X)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\pipeline.py:401: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   Xt = transform.transform(Xt)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\pipeline.py:401: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   Xt = transform.transform(Xt)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\preprocessing\data.py:645: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   return self.partial_fit(X, y)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\base.py:467: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   return self.fit(X, y, **fit_params).transform(X)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\pipeline.py:401: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   Xt = transform.transform(Xt)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\pipeline.py:401: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   Xt = transform.transform(Xt)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\preprocessing\data.py:645: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   return self.partial_fit(X, y)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\base.py:467: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   return self.fit(X, y, **fit_params).transform(X)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\pipeline.py:401: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   Xt = transform.transform(Xt)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\pipeline.py:401: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   Xt = transform.transform(Xt)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\preprocessing\data.py:645: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   return self.partial_fit(X, y)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\base.py:467: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   return self.fit(X, y, **fit_params).transform(X)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\pipeline.py:401: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   Xt = transform.transform(Xt)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\pipeline.py:401: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   Xt = transform.transform(Xt)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\preprocessing\data.py:645: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   return self.partial_fit(X, y)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\base.py:467: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   return self.fit(X, y, **fit_params).transform(X)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\pipeline.py:401: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   Xt = transform.transform(Xt)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\pipeline.py:401: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   Xt = transform.transform(Xt)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\preprocessing\data.py:645: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   return self.partial_fit(X, y)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\base.py:467: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   return self.fit(X, y, **fit_params).transform(X)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\pipeline.py:401: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   Xt = transform.transform(Xt)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\pipeline.py:401: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   Xt = transform.transform(Xt)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\preprocessing\data.py:645: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   return self.partial_fit(X, y)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\base.py:467: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   return self.fit(X, y, **fit_params).transform(X)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\pipeline.py:401: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   Xt = transform.transform(Xt)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\pipeline.py:401: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   Xt = transform.transform(Xt)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\preprocessing\data.py:645: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   return self.partial_fit(X, y)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\base.py:467: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   return self.fit(X, y, **fit_params).transform(X)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\pipeline.py:401: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   Xt = transform.transform(Xt)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\pipeline.py:401: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   Xt = transform.transform(Xt)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\preprocessing\data.py:645: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   return self.partial_fit(X, y)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\base.py:467: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   return self.fit(X, y, **fit_params).transform(X)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\pipeline.py:401: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   Xt = transform.transform(Xt)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\pipeline.py:401: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   Xt = transform.transform(Xt)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\preprocessing\data.py:645: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   return self.partial_fit(X, y)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\base.py:467: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   return self.fit(X, y, **fit_params).transform(X)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\pipeline.py:401: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   Xt = transform.transform(Xt)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\pipeline.py:401: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   Xt = transform.transform(Xt)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\preprocessing\data.py:645: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   return self.partial_fit(X, y)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\base.py:467: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   return self.fit(X, y, **fit_params).transform(X)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\pipeline.py:401: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   Xt = transform.transform(Xt)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\pipeline.py:401: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   Xt = transform.transform(Xt)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\preprocessing\data.py:645: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   return self.partial_fit(X, y)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\base.py:467: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   return self.fit(X, y, **fit_params).transform(X)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\pipeline.py:401: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   Xt = transform.transform(Xt)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\pipeline.py:401: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   Xt = transform.transform(Xt)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\preprocessing\data.py:645: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   return self.partial_fit(X, y)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\base.py:467: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   return self.fit(X, y, **fit_params).transform(X)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\pipeline.py:401: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   Xt = transform.transform(Xt)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\pipeline.py:401: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   Xt = transform.transform(Xt)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\preprocessing\data.py:645: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   return self.partial_fit(X, y)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\base.py:467: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   return self.fit(X, y, **fit_params).transform(X)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\pipeline.py:401: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   Xt = transform.transform(Xt)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\pipeline.py:401: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   Xt = transform.transform(Xt)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\preprocessing\data.py:645: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   return self.partial_fit(X, y)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\base.py:467: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   return self.fit(X, y, **fit_params).transform(X)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\pipeline.py:401: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   Xt = transform.transform(Xt)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\pipeline.py:401: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   Xt = transform.transform(Xt)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\preprocessing\data.py:645: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   return self.partial_fit(X, y)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\base.py:467: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   return self.fit(X, y, **fit_params).transform(X)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\pipeline.py:401: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   Xt = transform.transform(Xt)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\pipeline.py:401: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   Xt = transform.transform(Xt)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\preprocessing\data.py:645: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   return self.partial_fit(X, y)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\base.py:467: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   return self.fit(X, y, **fit_params).transform(X)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\pipeline.py:401: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   Xt = transform.transform(Xt)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\pipeline.py:401: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   Xt = transform.transform(Xt)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\preprocessing\data.py:645: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   return self.partial_fit(X, y)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\base.py:467: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   return self.fit(X, y, **fit_params).transform(X)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\pipeline.py:401: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   Xt = transform.transform(Xt)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\pipeline.py:401: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   Xt = transform.transform(Xt)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\preprocessing\data.py:645: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   return self.partial_fit(X, y)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\base.py:467: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   return self.fit(X, y, **fit_params).transform(X)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\pipeline.py:401: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   Xt = transform.transform(Xt)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\pipeline.py:401: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   Xt = transform.transform(Xt)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\preprocessing\data.py:645: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   return self.partial_fit(X, y)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\base.py:467: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   return self.fit(X, y, **fit_params).transform(X)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\pipeline.py:401: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   Xt = transform.transform(Xt)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\pipeline.py:401: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   Xt = transform.transform(Xt)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\preprocessing\data.py:645: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   return self.partial_fit(X, y)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\base.py:467: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   return self.fit(X, y, **fit_params).transform(X)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\pipeline.py:401: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   Xt = transform.transform(Xt)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\pipeline.py:401: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   Xt = transform.transform(Xt)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\preprocessing\data.py:645: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   return self.partial_fit(X, y)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\base.py:467: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   return self.fit(X, y, **fit_params).transform(X)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\pipeline.py:401: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   Xt = transform.transform(Xt)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\pipeline.py:401: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   Xt = transform.transform(Xt)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\preprocessing\data.py:645: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   return self.partial_fit(X, y)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\base.py:467: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   return self.fit(X, y, **fit_params).transform(X)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\pipeline.py:401: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   Xt = transform.transform(Xt)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\pipeline.py:401: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   Xt = transform.transform(Xt)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\preprocessing\data.py:645: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   return self.partial_fit(X, y)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\base.py:467: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   return self.fit(X, y, **fit_params).transform(X)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\pipeline.py:401: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   Xt = transform.transform(Xt)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\pipeline.py:401: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   Xt = transform.transform(Xt)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\preprocessing\data.py:645: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   return self.partial_fit(X, y)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\base.py:467: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   return self.fit(X, y, **fit_params).transform(X)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\pipeline.py:401: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   Xt = transform.transform(Xt)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\pipeline.py:401: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   Xt = transform.transform(Xt)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\preprocessing\data.py:645: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   return self.partial_fit(X, y)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\base.py:467: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   return self.fit(X, y, **fit_params).transform(X)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\pipeline.py:401: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   Xt = transform.transform(Xt)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\pipeline.py:401: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   Xt = transform.transform(Xt)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\preprocessing\data.py:645: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   return self.partial_fit(X, y)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\base.py:467: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   return self.fit(X, y, **fit_params).transform(X)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\pipeline.py:401: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   Xt = transform.transform(Xt)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\pipeline.py:401: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   Xt = transform.transform(Xt)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\preprocessing\data.py:645: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   return self.partial_fit(X, y)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\base.py:467: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   return self.fit(X, y, **fit_params).transform(X)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\pipeline.py:401: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   Xt = transform.transform(Xt)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\pipeline.py:401: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   Xt = transform.transform(Xt)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\preprocessing\data.py:645: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   return self.partial_fit(X, y)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\base.py:467: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   return self.fit(X, y, **fit_params).transform(X)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\pipeline.py:401: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   Xt = transform.transform(Xt)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\pipeline.py:401: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   Xt = transform.transform(Xt)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\preprocessing\data.py:645: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   return self.partial_fit(X, y)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\base.py:467: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   return self.fit(X, y, **fit_params).transform(X)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\pipeline.py:401: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   Xt = transform.transform(Xt)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\pipeline.py:401: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   Xt = transform.transform(Xt)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\preprocessing\data.py:645: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   return self.partial_fit(X, y)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\base.py:467: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   return self.fit(X, y, **fit_params).transform(X)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\pipeline.py:401: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   Xt = transform.transform(Xt)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\pipeline.py:401: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   Xt = transform.transform(Xt)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\preprocessing\data.py:645: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   return self.partial_fit(X, y)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\base.py:467: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   return self.fit(X, y, **fit_params).transform(X)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\pipeline.py:401: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   Xt = transform.transform(Xt)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\pipeline.py:401: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   Xt = transform.transform(Xt)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\preprocessing\data.py:645: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   return self.partial_fit(X, y)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\base.py:467: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   return self.fit(X, y, **fit_params).transform(X)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\pipeline.py:401: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   Xt = transform.transform(Xt)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\pipeline.py:401: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   Xt = transform.transform(Xt)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\preprocessing\data.py:645: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   return self.partial_fit(X, y)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\base.py:467: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   return self.fit(X, y, **fit_params).transform(X)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\pipeline.py:401: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   Xt = transform.transform(Xt)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\pipeline.py:401: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   Xt = transform.transform(Xt)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\preprocessing\data.py:645: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   return self.partial_fit(X, y)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\base.py:467: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   return self.fit(X, y, **fit_params).transform(X)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\pipeline.py:401: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   Xt = transform.transform(Xt)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\pipeline.py:401: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   Xt = transform.transform(Xt)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\preprocessing\data.py:645: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   return self.partial_fit(X, y)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\base.py:467: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   return self.fit(X, y, **fit_params).transform(X)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\pipeline.py:401: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   Xt = transform.transform(Xt)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\pipeline.py:401: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   Xt = transform.transform(Xt)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\preprocessing\data.py:645: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   return self.partial_fit(X, y)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\base.py:467: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   return self.fit(X, y, **fit_params).transform(X)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\pipeline.py:401: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   Xt = transform.transform(Xt)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\pipeline.py:401: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   Xt = transform.transform(Xt)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\preprocessing\data.py:645: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   return self.partial_fit(X, y)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\base.py:467: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   return self.fit(X, y, **fit_params).transform(X)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\pipeline.py:401: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   Xt = transform.transform(Xt)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\pipeline.py:401: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   Xt = transform.transform(Xt)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\preprocessing\data.py:645: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   return self.partial_fit(X, y)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\base.py:467: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   return self.fit(X, y, **fit_params).transform(X)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\pipeline.py:401: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   Xt = transform.transform(Xt)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\pipeline.py:401: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   Xt = transform.transform(Xt)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\preprocessing\data.py:645: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   return self.partial_fit(X, y)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\base.py:467: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   return self.fit(X, y, **fit_params).transform(X)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\pipeline.py:401: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   Xt = transform.transform(Xt)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\pipeline.py:401: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   Xt = transform.transform(Xt)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\preprocessing\data.py:645: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   return self.partial_fit(X, y)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\base.py:467: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   return self.fit(X, y, **fit_params).transform(X)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\pipeline.py:401: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   Xt = transform.transform(Xt)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\pipeline.py:401: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   Xt = transform.transform(Xt)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\preprocessing\data.py:645: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   return self.partial_fit(X, y)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\base.py:467: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   return self.fit(X, y, **fit_params).transform(X)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\pipeline.py:401: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   Xt = transform.transform(Xt)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\pipeline.py:401: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   Xt = transform.transform(Xt)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\preprocessing\data.py:645: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   return self.partial_fit(X, y)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\base.py:467: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   return self.fit(X, y, **fit_params).transform(X)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\pipeline.py:401: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   Xt = transform.transform(Xt)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\pipeline.py:401: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   Xt = transform.transform(Xt)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\preprocessing\data.py:645: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   return self.partial_fit(X, y)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\base.py:467: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   return self.fit(X, y, **fit_params).transform(X)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\pipeline.py:401: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   Xt = transform.transform(Xt)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\pipeline.py:401: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   Xt = transform.transform(Xt)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\preprocessing\data.py:645: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   return self.partial_fit(X, y)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\base.py:467: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   return self.fit(X, y, **fit_params).transform(X)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\pipeline.py:401: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   Xt = transform.transform(Xt)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\pipeline.py:401: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   Xt = transform.transform(Xt)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\preprocessing\data.py:645: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   return self.partial_fit(X, y)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\base.py:467: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   return self.fit(X, y, **fit_params).transform(X)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\pipeline.py:401: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   Xt = transform.transform(Xt)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\pipeline.py:401: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   Xt = transform.transform(Xt)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\preprocessing\data.py:645: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   return self.partial_fit(X, y)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\base.py:467: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   return self.fit(X, y, **fit_params).transform(X)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\pipeline.py:401: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   Xt = transform.transform(Xt)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\pipeline.py:401: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   Xt = transform.transform(Xt)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\preprocessing\data.py:645: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   return self.partial_fit(X, y)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\base.py:467: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   return self.fit(X, y, **fit_params).transform(X)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\pipeline.py:401: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   Xt = transform.transform(Xt)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\pipeline.py:401: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   Xt = transform.transform(Xt)
# ...
#   return self.fit(X, y, **fit_params).transform(X)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\pipeline.py:401: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   Xt = transform.transform(Xt)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\pipeline.py:401: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   Xt = transform.transform(Xt)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\preprocessing\data.py:645: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   return self.partial_fit(X, y)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\base.py:467: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   return self.fit(X, y, **fit_params).transform(X)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\pipeline.py:401: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   Xt = transform.transform(Xt)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\pipeline.py:401: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   Xt = transform.transform(Xt)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\preprocessing\data.py:645: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   return self.partial_fit(X, y)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\base.py:467: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   return self.fit(X, y, **fit_params).transform(X)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\pipeline.py:401: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   Xt = transform.transform(Xt)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\pipeline.py:401: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   Xt = transform.transform(Xt)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\preprocessing\data.py:645: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   return self.partial_fit(X, y)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\base.py:467: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   return self.fit(X, y, **fit_params).transform(X)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\pipeline.py:401: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   Xt = transform.transform(Xt)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\pipeline.py:401: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   Xt = transform.transform(Xt)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\preprocessing\data.py:645: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   return self.partial_fit(X, y)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\base.py:467: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   return self.fit(X, y, **fit_params).transform(X)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\pipeline.py:401: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   Xt = transform.transform(Xt)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\pipeline.py:401: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   Xt = transform.transform(Xt)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\preprocessing\data.py:645: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   return self.partial_fit(X, y)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\base.py:467: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   return self.fit(X, y, **fit_params).transform(X)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\pipeline.py:401: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   Xt = transform.transform(Xt)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\pipeline.py:401: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   Xt = transform.transform(Xt)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\preprocessing\data.py:645: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   return self.partial_fit(X, y)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\base.py:467: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   return self.fit(X, y, **fit_params).transform(X)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\pipeline.py:401: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   Xt = transform.transform(Xt)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\pipeline.py:401: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   Xt = transform.transform(Xt)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\preprocessing\data.py:645: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   return self.partial_fit(X, y)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\base.py:467: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   return self.fit(X, y, **fit_params).transform(X)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\pipeline.py:401: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   Xt = transform.transform(Xt)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\pipeline.py:401: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   Xt = transform.transform(Xt)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\preprocessing\data.py:645: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   return self.partial_fit(X, y)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\base.py:467: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   return self.fit(X, y, **fit_params).transform(X)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\pipeline.py:401: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   Xt = transform.transform(Xt)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\pipeline.py:401: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   Xt = transform.transform(Xt)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\preprocessing\data.py:645: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   return self.partial_fit(X, y)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\base.py:467: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   return self.fit(X, y, **fit_params).transform(X)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\pipeline.py:401: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   Xt = transform.transform(Xt)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\pipeline.py:401: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   Xt = transform.transform(Xt)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\preprocessing\data.py:645: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   return self.partial_fit(X, y)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\base.py:467: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   return self.fit(X, y, **fit_params).transform(X)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\pipeline.py:401: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   Xt = transform.transform(Xt)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\pipeline.py:401: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   Xt = transform.transform(Xt)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\preprocessing\data.py:645: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   return self.partial_fit(X, y)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\base.py:467: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   return self.fit(X, y, **fit_params).transform(X)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\pipeline.py:401: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   Xt = transform.transform(Xt)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\pipeline.py:401: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   Xt = transform.transform(Xt)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\preprocessing\data.py:645: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   return self.partial_fit(X, y)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\base.py:467: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   return self.fit(X, y, **fit_params).transform(X)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\pipeline.py:401: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   Xt = transform.transform(Xt)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\pipeline.py:401: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   Xt = transform.transform(Xt)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\preprocessing\data.py:645: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   return self.partial_fit(X, y)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\base.py:467: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   return self.fit(X, y, **fit_params).transform(X)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\pipeline.py:401: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   Xt = transform.transform(Xt)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\pipeline.py:401: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   Xt = transform.transform(Xt)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\preprocessing\data.py:645: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   return self.partial_fit(X, y)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\base.py:467: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   return self.fit(X, y, **fit_params).transform(X)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\pipeline.py:401: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   Xt = transform.transform(Xt)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\pipeline.py:401: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   Xt = transform.transform(Xt)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\preprocessing\data.py:645: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   return self.partial_fit(X, y)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\base.py:467: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   return self.fit(X, y, **fit_params).transform(X)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\pipeline.py:401: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   Xt = transform.transform(Xt)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\pipeline.py:401: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   Xt = transform.transform(Xt)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\preprocessing\data.py:645: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   return self.partial_fit(X, y)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\base.py:467: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   return self.fit(X, y, **fit_params).transform(X)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\pipeline.py:401: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   Xt = transform.transform(Xt)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\pipeline.py:401: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   Xt = transform.transform(Xt)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\preprocessing\data.py:645: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   return self.partial_fit(X, y)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\base.py:467: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   return self.fit(X, y, **fit_params).transform(X)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\pipeline.py:401: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   Xt = transform.transform(Xt)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\pipeline.py:401: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   Xt = transform.transform(Xt)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\model_selection\_search.py:841: DeprecationWarning: The default of the `iid` parameter will change from True to False in version 0.22 and will be removed in 0.24. This will change numeric results when test-set sizes are unequal.
#   DeprecationWarning)
# --> Tuned Parameters Best Score:  0.8767825585936605
# --> Best Parameters:
#  {'clf__C': 0.01, 'clf__kernel': 'linear'}
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\preprocessing\data.py:645: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   return self.partial_fit(X, y)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\base.py:467: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   return self.fit(X, y, **fit_params).transform(X)

# %%
#Use best parameters
clf_svc_auc = gs_svc_auc.best_estimator_

#Get Final Scores
clf_svc_auc.fit(X_train, y_train)
scores = cross_val_score(estimator=clf_svc_auc,
                         X=X_train,
                         y=y_train,
                         cv=10,
                         n_jobs=1)
print('--> Final Model Training AUC score: %.3f +/- %.3f' %(np.mean(scores), np.std(scores)))

print('--> Final AUC score on Test set: %.5f' % clf_svc_auc.score(X_test,y_test))
# Out:
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\preprocessing\data.py:645: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   return self.partial_fit(X, y)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\base.py:467: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   return self.fit(X, y, **fit_params).transform(X)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\preprocessing\data.py:645: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   return self.partial_fit(X, y)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\base.py:467: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   return self.fit(X, y, **fit_params).transform(X)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\pipeline.py:511: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   Xt = transform.transform(Xt)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\preprocessing\data.py:645: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   return self.partial_fit(X, y)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\base.py:467: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   return self.fit(X, y, **fit_params).transform(X)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\pipeline.py:511: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   Xt = transform.transform(Xt)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\preprocessing\data.py:645: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   return self.partial_fit(X, y)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\base.py:467: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   return self.fit(X, y, **fit_params).transform(X)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\pipeline.py:511: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   Xt = transform.transform(Xt)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\preprocessing\data.py:645: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   return self.partial_fit(X, y)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\base.py:467: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   return self.fit(X, y, **fit_params).transform(X)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\pipeline.py:511: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   Xt = transform.transform(Xt)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\preprocessing\data.py:645: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   return self.partial_fit(X, y)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\base.py:467: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   return self.fit(X, y, **fit_params).transform(X)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\pipeline.py:511: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   Xt = transform.transform(Xt)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\preprocessing\data.py:645: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   return self.partial_fit(X, y)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\base.py:467: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   return self.fit(X, y, **fit_params).transform(X)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\pipeline.py:511: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   Xt = transform.transform(Xt)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\preprocessing\data.py:645: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   return self.partial_fit(X, y)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\base.py:467: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   return self.fit(X, y, **fit_params).transform(X)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\pipeline.py:511: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   Xt = transform.transform(Xt)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\preprocessing\data.py:645: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   return self.partial_fit(X, y)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\base.py:467: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   return self.fit(X, y, **fit_params).transform(X)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\pipeline.py:511: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   Xt = transform.transform(Xt)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\preprocessing\data.py:645: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   return self.partial_fit(X, y)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\base.py:467: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   return self.fit(X, y, **fit_params).transform(X)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\pipeline.py:511: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   Xt = transform.transform(Xt)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\preprocessing\data.py:645: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   return self.partial_fit(X, y)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\base.py:467: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   return self.fit(X, y, **fit_params).transform(X)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\pipeline.py:511: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   Xt = transform.transform(Xt)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\pipeline.py:511: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   Xt = transform.transform(Xt)
# --> Final Model Training AUC score: 0.821 +/- 0.037
# --> Final AUC score on Test set: 0.75000

# %%
clf_svc_auc.fit(X_train, y_train)
y_pred_auc = clf_svc_auc.predict(X_test)
confmat_auc = confusion_matrix(y_true=y_test, y_pred=y_pred_auc)

print(accuracy_score(y_test, y_pred_auc))
print(confusion_matrix(y_test, y_pred_auc))
print(classification_report(y_test, y_pred_auc))
# Out:
# 0.75
# [[65 21]
#  [21 61]]
#               precision    recall  f1-score   support
#
#            0       0.74      0.79      0.76        86
#            1       0.76      0.71      0.73        82
#
#    micro avg       0.75      0.75      0.75       168
#    macro avg       0.75      0.75      0.75       168
# weighted avg       0.75      0.75      0.75       168
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\preprocessing\data.py:645: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   return self.partial_fit(X, y)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\base.py:467: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   return self.fit(X, y, **fit_params).transform(X)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\pipeline.py:331: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   Xt = transform.transform(Xt)

# %%
fig, ax = plt.subplots(figsize=(2.5, 2.5))
ax.matshow(confmat_auc, cmap=plt.cm.Blues, alpha=0.3)
for i in range(confmat_auc.shape[0]):
    for j in range(confmat_auc.shape[1]):
        ax.text(x=j, y=i, s=confmat_auc[i, j], va='center', ha='center')

plt.xlabel('predicted label')
plt.ylabel('true label')

plt.tight_layout()
plt.show()

# %%
param_range = [0.001, 0.01, 0.1, 1.0, 10.0, 100.0, 1000.0]


param_grid = [{'clf__C': param_range,'clf__kernel': ['linear']},
              {'clf__C': param_range,'clf__gamma': param_range,
               'clf__kernel': ['rbf'] }]

scores = {'accuracy': make_scorer(accuracy_score(y_true, y_pred, normalize=False)),
         'precision': make_scorer(precision_score), 
         'recall': make_scorer(recall_score)}

for score in scores:
    print("# Tuning hyper-parameters for %s" % score)
    print()

    gs = GridSearchCV(estimator=pipe_svc,
                  param_grid=param_grid,
                  cv=10,
                  n_jobs=1, 
                  scoring=score)
    
    gs.fit(X_train,y_train)
    
    print('--> Tuned Parameters Best Score: ',gs.best_score_)
    print()
    print('--> Best parameters set found on development set: \n',gs.best_params_)

    print()
    print("Grid scores on development set:")
    print()
    means = gs.cv_results_['mean_test_score']
    stds = gs.cv_results_['std_test_score']
    for mean, std, params in zip(means, stds, gs.cv_results_['params']):
        print("%0.3f (+/-%0.03f) for %r"
              % (mean, std * 2, params))
    print()
    
    clf= gs.best_estimator_

#Get Final Scores
    clf.fit(X_train, y_train)
    scores = cross_val_score(estimator=clf,
                         X=X_train,
                         y=y_train,
                         cv=10,
                         n_jobs=1)
    
    print('--> Final Model Training Accuracy score: %.3f +/- %.3f' %(np.mean(scores), np.std(scores)))
    print()
    print('--> Final Accuracy score on Test set: %.5f' % clf.score(X_test,y_test))

    y_true, y_pred = y_test, clf.predict(X_test)
 
    confmat = confusion_matrix(y_true, y_pred)
   
    print()
    print("Confusion matrix:")
    print(confusion_matrix(y_true, y_pred))
    print()
    print("Detailed classification report:")
    print(classification_report(y_true, y_pred))
    print()
    
    pipelines.append(('svc', clf))
    
    fig, ax = plt.subplots(figsize=(2.5, 2.5))
    ax.matshow(confmat, cmap=plt.cm.Blues, alpha=0.3)
    for i in range(confmat.shape[0]):
        for j in range(confmat.shape[1]):
            ax.text(x=j, y=i, s=confmat[i, j], va='center', ha='center')

    plt.xlabel('predicted label')
    plt.ylabel('true label')

    plt.tight_layout()
    plt.show()
# Out:
# # Tuning hyper-parameters for accuracy
#
# --> Tuned Parameters Best Score:  0.8233532934131736
#
# --> Best parameters set found on development set:
#  {'clf__C': 0.001, 'clf__kernel': 'linear'}
#
# Grid scores on development set:
#
# 0.823 (+/-0.069) for {'clf__C': 0.001, 'clf__kernel': 'linear'}
# 0.819 (+/-0.075) for {'clf__C': 0.01, 'clf__kernel': 'linear'}
# 0.817 (+/-0.083) for {'clf__C': 0.1, 'clf__kernel': 'linear'}
# 0.814 (+/-0.088) for {'clf__C': 1.0, 'clf__kernel': 'linear'}
# 0.814 (+/-0.088) for {'clf__C': 10.0, 'clf__kernel': 'linear'}
# 0.814 (+/-0.088) for {'clf__C': 100.0, 'clf__kernel': 'linear'}
# 0.814 (+/-0.088) for {'clf__C': 1000.0, 'clf__kernel': 'linear'}
# 0.512 (+/-0.007) for {'clf__C': 0.001, 'clf__gamma': 0.001, 'clf__kernel': 'rbf'}
# 0.512 (+/-0.007) for {'clf__C': 0.001, 'clf__gamma': 0.01, 'clf__kernel': 'rbf'}
# 0.512 (+/-0.007) for {'clf__C': 0.001, 'clf__gamma': 0.1, 'clf__kernel': 'rbf'}
# 0.512 (+/-0.007) for {'clf__C': 0.001, 'clf__gamma': 1.0, 'clf__kernel': 'rbf'}
# 0.512 (+/-0.007) for {'clf__C': 0.001, 'clf__gamma': 10.0, 'clf__kernel': 'rbf'}
# 0.512 (+/-0.007) for {'clf__C': 0.001, 'clf__gamma': 100.0, 'clf__kernel': 'rbf'}
# 0.512 (+/-0.007) for {'clf__C': 0.001, 'clf__gamma': 1000.0, 'clf__kernel': 'rbf'}
# 0.512 (+/-0.007) for {'clf__C': 0.01, 'clf__gamma': 0.001, 'clf__kernel': 'rbf'}
# 0.512 (+/-0.007) for {'clf__C': 0.01, 'clf__gamma': 0.01, 'clf__kernel': 'rbf'}
# 0.822 (+/-0.072) for {'clf__C': 0.01, 'clf__gamma': 0.1, 'clf__kernel': 'rbf'}
# 0.769 (+/-0.087) for {'clf__C': 0.01, 'clf__gamma': 1.0, 'clf__kernel': 'rbf'}
# 0.512 (+/-0.007) for {'clf__C': 0.01, 'clf__gamma': 10.0, 'clf__kernel': 'rbf'}
# 0.512 (+/-0.007) for {'clf__C': 0.01, 'clf__gamma': 100.0, 'clf__kernel': 'rbf'}
# 0.512 (+/-0.007) for {'clf__C': 0.01, 'clf__gamma': 1000.0, 'clf__kernel': 'rbf'}
# 0.512 (+/-0.007) for {'clf__C': 0.1, 'clf__gamma': 0.001, 'clf__kernel': 'rbf'}
# 0.823 (+/-0.068) for {'clf__C': 0.1, 'clf__gamma': 0.01, 'clf__kernel': 'rbf'}
# 0.822 (+/-0.074) for {'clf__C': 0.1, 'clf__gamma': 0.1, 'clf__kernel': 'rbf'}
# 0.807 (+/-0.092) for {'clf__C': 0.1, 'clf__gamma': 1.0, 'clf__kernel': 'rbf'}
# 0.796 (+/-0.092) for {'clf__C': 0.1, 'clf__gamma': 10.0, 'clf__kernel': 'rbf'}
# 0.787 (+/-0.098) for {'clf__C': 0.1, 'clf__gamma': 100.0, 'clf__kernel': 'rbf'}
# 0.543 (+/-0.046) for {'clf__C': 0.1, 'clf__gamma': 1000.0, 'clf__kernel': 'rbf'}
# 0.823 (+/-0.069) for {'clf__C': 1.0, 'clf__gamma': 0.001, 'clf__kernel': 'rbf'}
# 0.820 (+/-0.073) for {'clf__C': 1.0, 'clf__gamma': 0.01, 'clf__kernel': 'rbf'}
# 0.808 (+/-0.096) for {'clf__C': 1.0, 'clf__gamma': 0.1, 'clf__kernel': 'rbf'}
# 0.814 (+/-0.093) for {'clf__C': 1.0, 'clf__gamma': 1.0, 'clf__kernel': 'rbf'}
# 0.796 (+/-0.081) for {'clf__C': 1.0, 'clf__gamma': 10.0, 'clf__kernel': 'rbf'}
# 0.789 (+/-0.094) for {'clf__C': 1.0, 'clf__gamma': 100.0, 'clf__kernel': 'rbf'}
# 0.772 (+/-0.091) for {'clf__C': 1.0, 'clf__gamma': 1000.0, 'clf__kernel': 'rbf'}
# 0.820 (+/-0.077) for {'clf__C': 10.0, 'clf__gamma': 0.001, 'clf__kernel': 'rbf'}
# 0.807 (+/-0.073) for {'clf__C': 10.0, 'clf__gamma': 0.01, 'clf__kernel': 'rbf'}
# 0.810 (+/-0.098) for {'clf__C': 10.0, 'clf__gamma': 0.1, 'clf__kernel': 'rbf'}
# 0.805 (+/-0.098) for {'clf__C': 10.0, 'clf__gamma': 1.0, 'clf__kernel': 'rbf'}
# 0.793 (+/-0.089) for {'clf__C': 10.0, 'clf__gamma': 10.0, 'clf__kernel': 'rbf'}
# 0.777 (+/-0.115) for {'clf__C': 10.0, 'clf__gamma': 100.0, 'clf__kernel': 'rbf'}
# 0.757 (+/-0.100) for {'clf__C': 10.0, 'clf__gamma': 1000.0, 'clf__kernel': 'rbf'}
# 0.816 (+/-0.084) for {'clf__C': 100.0, 'clf__gamma': 0.001, 'clf__kernel': 'rbf'}
# 0.804 (+/-0.085) for {'clf__C': 100.0, 'clf__gamma': 0.01, 'clf__kernel': 'rbf'}
# 0.811 (+/-0.096) for {'clf__C': 100.0, 'clf__gamma': 0.1, 'clf__kernel': 'rbf'}
# 0.801 (+/-0.088) for {'clf__C': 100.0, 'clf__gamma': 1.0, 'clf__kernel': 'rbf'}
# 0.790 (+/-0.105) for {'clf__C': 100.0, 'clf__gamma': 10.0, 'clf__kernel': 'rbf'}
# 0.777 (+/-0.100) for {'clf__C': 100.0, 'clf__gamma': 100.0, 'clf__kernel': 'rbf'}
# 0.757 (+/-0.100) for {'clf__C': 100.0, 'clf__gamma': 1000.0, 'clf__kernel': 'rbf'}
# 0.807 (+/-0.073) for {'clf__C': 1000.0, 'clf__gamma': 0.001, 'clf__kernel': 'rbf'}
# 0.805 (+/-0.102) for {'clf__C': 1000.0, 'clf__gamma': 0.01, 'clf__kernel': 'rbf'}
# 0.813 (+/-0.110) for {'clf__C': 1000.0, 'clf__gamma': 0.1, 'clf__kernel': 'rbf'}
# 0.795 (+/-0.099) for {'clf__C': 1000.0, 'clf__gamma': 1.0, 'clf__kernel': 'rbf'}
# 0.792 (+/-0.102) for {'clf__C': 1000.0, 'clf__gamma': 10.0, 'clf__kernel': 'rbf'}
# 0.771 (+/-0.107) for {'clf__C': 1000.0, 'clf__gamma': 100.0, 'clf__kernel': 'rbf'}
# 0.757 (+/-0.100) for {'clf__C': 1000.0, 'clf__gamma': 1000.0, 'clf__kernel': 'rbf'}
#
# --> Final Model Training Accuracy score: 0.823 +/- 0.035
#
# --> Final Accuracy score on Test set: 0.75595
#
# Confusion matrix:
# [[65 21]
#  [20 62]]
#
# Detailed classification report:
#               precision    recall  f1-score   support
#
#            0       0.76      0.76      0.76        86
#            1       0.75      0.76      0.75        82
#
#    micro avg       0.76      0.76      0.76       168
#    macro avg       0.76      0.76      0.76       168
# weighted avg       0.76      0.76      0.76       168
# # Tuning hyper-parameters for precision
#
# --> Tuned Parameters Best Score:  0.7967160586418489
#
# --> Best parameters set found on development set:
#  {'clf__C': 0.01, 'clf__gamma': 1.0, 'clf__kernel': 'rbf'}
#
# Grid scores on development set:
#
# 0.772 (+/-0.087) for {'clf__C': 0.001, 'clf__kernel': 'linear'}
# 0.775 (+/-0.093) for {'clf__C': 0.01, 'clf__kernel': 'linear'}
# 0.777 (+/-0.093) for {'clf__C': 0.1, 'clf__kernel': 'linear'}
# 0.775 (+/-0.096) for {'clf__C': 1.0, 'clf__kernel': 'linear'}
# 0.775 (+/-0.096) for {'clf__C': 10.0, 'clf__kernel': 'linear'}
# 0.775 (+/-0.096) for {'clf__C': 100.0, 'clf__kernel': 'linear'}
# 0.775 (+/-0.096) for {'clf__C': 1000.0, 'clf__kernel': 'linear'}
# 0.000 (+/-0.000) for {'clf__C': 0.001, 'clf__gamma': 0.001, 'clf__kernel': 'rbf'}
# 0.000 (+/-0.000) for {'clf__C': 0.001, 'clf__gamma': 0.01, 'clf__kernel': 'rbf'}
# 0.000 (+/-0.000) for {'clf__C': 0.001, 'clf__gamma': 0.1, 'clf__kernel': 'rbf'}
# 0.000 (+/-0.000) for {'clf__C': 0.001, 'clf__gamma': 1.0, 'clf__kernel': 'rbf'}
# 0.000 (+/-0.000) for {'clf__C': 0.001, 'clf__gamma': 10.0, 'clf__kernel': 'rbf'}
# 0.000 (+/-0.000) for {'clf__C': 0.001, 'clf__gamma': 100.0, 'clf__kernel': 'rbf'}
# 0.000 (+/-0.000) for {'clf__C': 0.001, 'clf__gamma': 1000.0, 'clf__kernel': 'rbf'}
# 0.000 (+/-0.000) for {'clf__C': 0.01, 'clf__gamma': 0.001, 'clf__kernel': 'rbf'}
# 0.000 (+/-0.000) for {'clf__C': 0.01, 'clf__gamma': 0.01, 'clf__kernel': 'rbf'}
# 0.767 (+/-0.087) for {'clf__C': 0.01, 'clf__gamma': 0.1, 'clf__kernel': 'rbf'}
# 0.797 (+/-0.098) for {'clf__C': 0.01, 'clf__gamma': 1.0, 'clf__kernel': 'rbf'}
# 0.000 (+/-0.000) for {'clf__C': 0.01, 'clf__gamma': 10.0, 'clf__kernel': 'rbf'}
# 0.000 (+/-0.000) for {'clf__C': 0.01, 'clf__gamma': 100.0, 'clf__kernel': 'rbf'}
# 0.000 (+/-0.000) for {'clf__C': 0.01, 'clf__gamma': 1000.0, 'clf__kernel': 'rbf'}
# 0.000 (+/-0.000) for {'clf__C': 0.1, 'clf__gamma': 0.001, 'clf__kernel': 'rbf'}
# 0.771 (+/-0.089) for {'clf__C': 0.1, 'clf__gamma': 0.01, 'clf__kernel': 'rbf'}
# 0.772 (+/-0.094) for {'clf__C': 0.1, 'clf__gamma': 0.1, 'clf__kernel': 'rbf'}
# 0.766 (+/-0.101) for {'clf__C': 0.1, 'clf__gamma': 1.0, 'clf__kernel': 'rbf'}
# 0.758 (+/-0.086) for {'clf__C': 0.1, 'clf__gamma': 10.0, 'clf__kernel': 'rbf'}
# 0.775 (+/-0.100) for {'clf__C': 0.1, 'clf__gamma': 100.0, 'clf__kernel': 'rbf'}
# 0.760 (+/-0.415) for {'clf__C': 0.1, 'clf__gamma': 1000.0, 'clf__kernel': 'rbf'}
# 0.772 (+/-0.087) for {'clf__C': 1.0, 'clf__gamma': 0.001, 'clf__kernel': 'rbf'}
# 0.777 (+/-0.089) for {'clf__C': 1.0, 'clf__gamma': 0.01, 'clf__kernel': 'rbf'}
# 0.771 (+/-0.099) for {'clf__C': 1.0, 'clf__gamma': 0.1, 'clf__kernel': 'rbf'}
# 0.780 (+/-0.101) for {'clf__C': 1.0, 'clf__gamma': 1.0, 'clf__kernel': 'rbf'}
# 0.765 (+/-0.076) for {'clf__C': 1.0, 'clf__gamma': 10.0, 'clf__kernel': 'rbf'}
# 0.746 (+/-0.082) for {'clf__C': 1.0, 'clf__gamma': 100.0, 'clf__kernel': 'rbf'}
# 0.752 (+/-0.119) for {'clf__C': 1.0, 'clf__gamma': 1000.0, 'clf__kernel': 'rbf'}
# 0.778 (+/-0.092) for {'clf__C': 10.0, 'clf__gamma': 0.001, 'clf__kernel': 'rbf'}
# 0.768 (+/-0.099) for {'clf__C': 10.0, 'clf__gamma': 0.01, 'clf__kernel': 'rbf'}
# 0.774 (+/-0.099) for {'clf__C': 10.0, 'clf__gamma': 0.1, 'clf__kernel': 'rbf'}
# 0.771 (+/-0.102) for {'clf__C': 10.0, 'clf__gamma': 1.0, 'clf__kernel': 'rbf'}
# 0.762 (+/-0.079) for {'clf__C': 10.0, 'clf__gamma': 10.0, 'clf__kernel': 'rbf'}
# 0.740 (+/-0.102) for {'clf__C': 10.0, 'clf__gamma': 100.0, 'clf__kernel': 'rbf'}
# 0.756 (+/-0.128) for {'clf__C': 10.0, 'clf__gamma': 1000.0, 'clf__kernel': 'rbf'}
# 0.776 (+/-0.094) for {'clf__C': 100.0, 'clf__gamma': 0.001, 'clf__kernel': 'rbf'}
# 0.766 (+/-0.096) for {'clf__C': 100.0, 'clf__gamma': 0.01, 'clf__kernel': 'rbf'}
# 0.776 (+/-0.096) for {'clf__C': 100.0, 'clf__gamma': 0.1, 'clf__kernel': 'rbf'}
# 0.763 (+/-0.096) for {'clf__C': 100.0, 'clf__gamma': 1.0, 'clf__kernel': 'rbf'}
# 0.761 (+/-0.097) for {'clf__C': 100.0, 'clf__gamma': 10.0, 'clf__kernel': 'rbf'}
# 0.745 (+/-0.109) for {'clf__C': 100.0, 'clf__gamma': 100.0, 'clf__kernel': 'rbf'}
# 0.756 (+/-0.128) for {'clf__C': 100.0, 'clf__gamma': 1000.0, 'clf__kernel': 'rbf'}
# 0.768 (+/-0.099) for {'clf__C': 1000.0, 'clf__gamma': 0.001, 'clf__kernel': 'rbf'}
# 0.770 (+/-0.103) for {'clf__C': 1000.0, 'clf__gamma': 0.01, 'clf__kernel': 'rbf'}
# 0.782 (+/-0.114) for {'clf__C': 1000.0, 'clf__gamma': 0.1, 'clf__kernel': 'rbf'}
# 0.761 (+/-0.092) for {'clf__C': 1000.0, 'clf__gamma': 1.0, 'clf__kernel': 'rbf'}
# 0.765 (+/-0.097) for {'clf__C': 1000.0, 'clf__gamma': 10.0, 'clf__kernel': 'rbf'}
# 0.734 (+/-0.111) for {'clf__C': 1000.0, 'clf__gamma': 100.0, 'clf__kernel': 'rbf'}
# 0.756 (+/-0.128) for {'clf__C': 1000.0, 'clf__gamma': 1000.0, 'clf__kernel': 'rbf'}
#
# --> Final Model Training Accuracy score: 0.770 +/- 0.044
#
# --> Final Accuracy score on Test set: 0.72024
#
# Confusion matrix:
# [[69 17]
#  [30 52]]
#
# Detailed classification report:
#               precision    recall  f1-score   support
#
#            0       0.70      0.80      0.75        86
#            1       0.75      0.63      0.69        82
#
#    micro avg       0.72      0.72      0.72       168
#    macro avg       0.73      0.72      0.72       168
# weighted avg       0.72      0.72      0.72       168
# # Tuning hyper-parameters for recall
#
# --> Tuned Parameters Best Score:  0.9172280439121755
#
# --> Best parameters set found on development set:
#  {'clf__C': 0.01, 'clf__gamma': 0.1, 'clf__kernel': 'rbf'}
#
# Grid scores on development set:
#
# 0.911 (+/-0.084) for {'clf__C': 0.001, 'clf__kernel': 'linear'}
# 0.893 (+/-0.100) for {'clf__C': 0.01, 'clf__kernel': 'linear'}
# 0.883 (+/-0.131) for {'clf__C': 0.1, 'clf__kernel': 'linear'}
# 0.877 (+/-0.137) for {'clf__C': 1.0, 'clf__kernel': 'linear'}
# 0.877 (+/-0.137) for {'clf__C': 10.0, 'clf__kernel': 'linear'}
# 0.877 (+/-0.137) for {'clf__C': 100.0, 'clf__kernel': 'linear'}
# 0.877 (+/-0.137) for {'clf__C': 1000.0, 'clf__kernel': 'linear'}
# 0.000 (+/-0.000) for {'clf__C': 0.001, 'clf__gamma': 0.001, 'clf__kernel': 'rbf'}
# 0.000 (+/-0.000) for {'clf__C': 0.001, 'clf__gamma': 0.01, 'clf__kernel': 'rbf'}
# 0.000 (+/-0.000) for {'clf__C': 0.001, 'clf__gamma': 0.1, 'clf__kernel': 'rbf'}
# 0.000 (+/-0.000) for {'clf__C': 0.001, 'clf__gamma': 1.0, 'clf__kernel': 'rbf'}
# 0.000 (+/-0.000) for {'clf__C': 0.001, 'clf__gamma': 10.0, 'clf__kernel': 'rbf'}
# 0.000 (+/-0.000) for {'clf__C': 0.001, 'clf__gamma': 100.0, 'clf__kernel': 'rbf'}
# 0.000 (+/-0.000) for {'clf__C': 0.001, 'clf__gamma': 1000.0, 'clf__kernel': 'rbf'}
# 0.000 (+/-0.000) for {'clf__C': 0.01, 'clf__gamma': 0.001, 'clf__kernel': 'rbf'}
# 0.000 (+/-0.000) for {'clf__C': 0.01, 'clf__gamma': 0.01, 'clf__kernel': 'rbf'}
# 0.917 (+/-0.087) for {'clf__C': 0.01, 'clf__gamma': 0.1, 'clf__kernel': 'rbf'}
# 0.708 (+/-0.127) for {'clf__C': 0.01, 'clf__gamma': 1.0, 'clf__kernel': 'rbf'}
# 0.000 (+/-0.000) for {'clf__C': 0.01, 'clf__gamma': 10.0, 'clf__kernel': 'rbf'}
# 0.000 (+/-0.000) for {'clf__C': 0.01, 'clf__gamma': 100.0, 'clf__kernel': 'rbf'}
# 0.000 (+/-0.000) for {'clf__C': 0.01, 'clf__gamma': 1000.0, 'clf__kernel': 'rbf'}
# 0.000 (+/-0.000) for {'clf__C': 0.1, 'clf__gamma': 0.001, 'clf__kernel': 'rbf'}
# 0.914 (+/-0.077) for {'clf__C': 0.1, 'clf__gamma': 0.01, 'clf__kernel': 'rbf'}
# 0.908 (+/-0.095) for {'clf__C': 0.1, 'clf__gamma': 0.1, 'clf__kernel': 'rbf'}
# 0.877 (+/-0.162) for {'clf__C': 0.1, 'clf__gamma': 1.0, 'clf__kernel': 'rbf'}
# 0.859 (+/-0.162) for {'clf__C': 0.1, 'clf__gamma': 10.0, 'clf__kernel': 'rbf'}
# 0.798 (+/-0.156) for {'clf__C': 0.1, 'clf__gamma': 100.0, 'clf__kernel': 'rbf'}
# 0.098 (+/-0.086) for {'clf__C': 0.1, 'clf__gamma': 1000.0, 'clf__kernel': 'rbf'}
# 0.911 (+/-0.084) for {'clf__C': 1.0, 'clf__gamma': 0.001, 'clf__kernel': 'rbf'}
# 0.893 (+/-0.111) for {'clf__C': 1.0, 'clf__gamma': 0.01, 'clf__kernel': 'rbf'}
# 0.868 (+/-0.164) for {'clf__C': 1.0, 'clf__gamma': 0.1, 'clf__kernel': 'rbf'}
# 0.868 (+/-0.155) for {'clf__C': 1.0, 'clf__gamma': 1.0, 'clf__kernel': 'rbf'}
# 0.844 (+/-0.137) for {'clf__C': 1.0, 'clf__gamma': 10.0, 'clf__kernel': 'rbf'}
# 0.862 (+/-0.150) for {'clf__C': 1.0, 'clf__gamma': 100.0, 'clf__kernel': 'rbf'}
# 0.807 (+/-0.147) for {'clf__C': 1.0, 'clf__gamma': 1000.0, 'clf__kernel': 'rbf'}
# 0.890 (+/-0.111) for {'clf__C': 10.0, 'clf__gamma': 0.001, 'clf__kernel': 'rbf'}
# 0.874 (+/-0.146) for {'clf__C': 10.0, 'clf__gamma': 0.01, 'clf__kernel': 'rbf'}
# 0.865 (+/-0.157) for {'clf__C': 10.0, 'clf__gamma': 0.1, 'clf__kernel': 'rbf'}
# 0.859 (+/-0.167) for {'clf__C': 10.0, 'clf__gamma': 1.0, 'clf__kernel': 'rbf'}
# 0.841 (+/-0.143) for {'clf__C': 10.0, 'clf__gamma': 10.0, 'clf__kernel': 'rbf'}
# 0.838 (+/-0.177) for {'clf__C': 10.0, 'clf__gamma': 100.0, 'clf__kernel': 'rbf'}
# 0.755 (+/-0.208) for {'clf__C': 10.0, 'clf__gamma': 1000.0, 'clf__kernel': 'rbf'}
# 0.880 (+/-0.127) for {'clf__C': 100.0, 'clf__gamma': 0.001, 'clf__kernel': 'rbf'}
# 0.868 (+/-0.164) for {'clf__C': 100.0, 'clf__gamma': 0.01, 'clf__kernel': 'rbf'}
# 0.865 (+/-0.153) for {'clf__C': 100.0, 'clf__gamma': 0.1, 'clf__kernel': 'rbf'}
# 0.862 (+/-0.137) for {'clf__C': 100.0, 'clf__gamma': 1.0, 'clf__kernel': 'rbf'}
# 0.831 (+/-0.145) for {'clf__C': 100.0, 'clf__gamma': 10.0, 'clf__kernel': 'rbf'}
# 0.831 (+/-0.130) for {'clf__C': 100.0, 'clf__gamma': 100.0, 'clf__kernel': 'rbf'}
# 0.755 (+/-0.208) for {'clf__C': 100.0, 'clf__gamma': 1000.0, 'clf__kernel': 'rbf'}
# 0.874 (+/-0.146) for {'clf__C': 1000.0, 'clf__gamma': 0.001, 'clf__kernel': 'rbf'}
# 0.862 (+/-0.169) for {'clf__C': 1000.0, 'clf__gamma': 0.01, 'clf__kernel': 'rbf'}
# 0.859 (+/-0.165) for {'clf__C': 1000.0, 'clf__gamma': 0.1, 'clf__kernel': 'rbf'}
# 0.847 (+/-0.139) for {'clf__C': 1000.0, 'clf__gamma': 1.0, 'clf__kernel': 'rbf'}
# 0.828 (+/-0.142) for {'clf__C': 1000.0, 'clf__gamma': 10.0, 'clf__kernel': 'rbf'}
# 0.837 (+/-0.122) for {'clf__C': 1000.0, 'clf__gamma': 100.0, 'clf__kernel': 'rbf'}
# 0.755 (+/-0.208) for {'clf__C': 1000.0, 'clf__gamma': 1000.0, 'clf__kernel': 'rbf'}
#
# --> Final Model Training Accuracy score: 0.822 +/- 0.036
#
# --> Final Accuracy score on Test set: 0.75000
#
# Confusion matrix:
# [[63 23]
#  [19 63]]
#
# Detailed classification report:
#               precision    recall  f1-score   support
#
#            0       0.77      0.73      0.75        86
#            1       0.73      0.77      0.75        82
#
#    micro avg       0.75      0.75      0.75       168
#    macro avg       0.75      0.75      0.75       168
# weighted avg       0.75      0.75      0.75       168

# %%
import matplotlib.pyplot as plt
from sklearn.model_selection import learning_curve


pipe_svm = Pipeline(StandardScaler(),
                        svm.SVC(C=0.1, kernel='linear', gamma = 1, degree = 4, random_state = 1))

train_sizes, train_scores, test_scores =\
                learning_curve(estimator=pipe_svm,
                               X=X_train,
                               y=y_train,
                               train_sizes=np.linspace(0.1, 1.0, 10),
                               cv=10,
                               n_jobs=1)

train_mean = np.mean(train_scores, axis=1)
train_std = np.std(train_scores, axis=1)
test_mean = np.mean(test_scores, axis=1)
test_std = np.std(test_scores, axis=1)

plt.plot(train_sizes, train_mean,
         color='blue', marker='o',
         markersize=5, label='training accuracy')

plt.fill_between(train_sizes,
                 train_mean + train_std,
                 train_mean - train_std,
                 alpha=0.15, color='blue')

plt.plot(train_sizes, test_mean,
         color='green', linestyle='--',
         marker='s', markersize=5,
         label='validation accuracy')

plt.fill_between(train_sizes,
                 test_mean + test_std,
                 test_mean - test_std,
                 alpha=0.15, color='green')

plt.grid()
plt.xlabel('Number of training samples')
plt.ylabel('Accuracy')
plt.legend(loc='lower right')
plt.ylim([0.6, 1])
plt.tight_layout()
#plt.savefig('images/06_05.png', dpi=300)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-39-7c013dce2489> in <module>
#       4
#       5 pipe_svm = Pipeline(StandardScaler(),
# ----> 6                         svm.SVC(C=0.1, kernel='linear', gamma = 1, degree = 4, random_state = 1))
#       7
#       8 train_sizes, train_scores, test_scores =\
#
# NameError: name 'svm' is not defined

# %%
from sklearn.model_selection import validation_curve

#finding the optimal value of C using validation curve
param_range = [0.005, 0.01, 0.05, 0.1, 0.5, 1.0, 10.0, 100.0, 250.0]
train_scores, test_scores = validation_curve(
                estimator=svm.SVC(), 
                X=X_train, 
                y=y_train, 
                param_name='C', 
                param_range =param_range, cv= 10)



train_mean = np.mean(train_scores, axis=1)
train_std = np.std(train_scores, axis=1)
test_mean = np.mean(test_scores, axis=1)
test_std = np.std(test_scores, axis=1)

plt.plot(param_range, train_mean, 
         color='blue', marker='o', 
         markersize=5, label='training accuracy')

plt.fill_between(param_range, train_mean + train_std,
                 train_mean - train_std, alpha=0.15,
                 color='blue')

plt.plot(param_range, test_mean, 
         color='green', linestyle='--', 
         marker='s', markersize=5, 
         label='validation accuracy')

plt.fill_between(param_range, 
                 test_mean + test_std,
                 test_mean - test_std, 
                 alpha=0.15, color='green')

#plotting the C paramater values agains the relevant accuracy values
plt.grid()
plt.legend(loc='lower right')
plt.xlabel('Parameter C')
plt.ylabel('Accuracy')
plt.ylim([0.6, 1.0])
plt.xlim([0, 10.3])
plt.tight_layout()
plt.show()

# %%
from sklearn.model_selection import validation_curve


train_scores, test_scores = validation_curve(
                estimator=svm.SVC(), 
                X=X_train, 
                y=y_train, 
                param_name='degree', 
                param_range = [1,2,3,4,5,6], cv= 10)



train_mean = np.mean(train_scores, axis=1)
train_std = np.std(train_scores, axis=1)
test_mean = np.mean(test_scores, axis=1)
test_std = np.std(test_scores, axis=1)

plt.plot(param_range, train_mean, 
         color='blue', marker='o', 
         markersize=5, label='training accuracy')

plt.fill_between(param_range, train_mean + train_std,
                 train_mean - train_std, alpha=0.15,
                 color='blue')

plt.plot(param_range, test_mean, 
         color='green', linestyle='--', 
         marker='s', markersize=5, 
         label='validation accuracy')

plt.fill_between(param_range, 
                 test_mean + test_std,
                 test_mean - test_std, 
                 alpha=0.15, color='green')

plt.grid()
#plt.xscale('log')
plt.legend(loc='lower right')
plt.xlabel('Parameter C')
plt.ylabel('Accuracy')
plt.ylim([0.6, 1.0])
plt.xlim([0, 10.3])
plt.tight_layout()
plt.show()

# %%
from sklearn.tree import DecisionTreeClassifier

gs = GridSearchCV(estimator=DecisionTreeClassifier(random_state=0),
                  param_grid=[{'max_depth': [1, 2, 3, 4, 5, 6, 7, None]}],
                  scoring='accuracy',
                  cv=2)

scores = cross_val_score(gs, X_train, y_train, 
                         scoring='accuracy', cv=5)
print('CV accuracy: %.3f +/- %.3f' % (np.mean(scores), 
                                      np.std(scores)))
# Out:
# CV accuracy: 0.812 +/- 0.033

# %%
from sklearn.neural_network import MLPClassifier
from sklearn.model_selection import GridSearchCV

# %%
from sklearn.dummy import DummyClassifier
pipe_Dummy = Pipeline([('scl', StandardScaler()), #not needed because most frequent class label used for prediction only
                     ('clf', DummyClassifier(strategy="most_frequent"))])

pipelines.append(( 'ScaledDummy', pipe_Dummy))

# %%
from sklearn.preprocessing import StandardScaler
import numpy as np

data = X
scaler = StandardScaler()
scaled_data = scaler.fit_transform(data)

# %%
#importing train test split module
from sklearn.model_selection import train_test_split

#split the data into training and testing sets, 80% of data will be used for training and 20% of data is kept aside for testing
X_train, X_test, y_train, y_test = \
    train_test_split(scaled_data, y, 
                     test_size=0.20,
                     stratify=y,
                     random_state=1)

# %%
mlp = MLPClassifier(max_iter=100)
#Tuning hyperparameters, specifing a range of values for the GridSearch to select the optimal hyperparamater values
parameter_space = {
    'hidden_layer_sizes': [(50,50,50), (50,100,50), (100,100,100), (100,50,100),(100,150,100)],
    'activation': ['tanh', 'relu'],
    'solver': ['sgd', 'adam'],
    'alpha': [0.0001, 0.001, 0.01,0.05, 1],
    'learning_rate': ['constant','adaptive'],
}


scores = {'accuracy': make_scorer(accuracy_score(y_true, y_pred, normalize=False)),
         'precision': make_scorer(precision_score), 
         'recall': make_scorer(recall_score)}

for score in scores:
    print("# Tuning hyper-parameters for %s" % score)
    print()

   #Using GridSearch to optimise for Accuracy
    gs_mlp =GridSearchCV(mlp, parameter_space, n_jobs=-1, cv=3,scoring='accuracy')

#Fitting Gridsearch to the training data
    gs_mlp = gs_mlp.fit(X_train, y_train)
    
    print('--> Tuned Parameters Best Score: ',gs_mlp.best_score_)
    print()
    print('--> Best parameters set found on development set: \n',gs_mlp.best_params_)

    print()
    print("Grid scores on development set:")
    print()
    means = gs_mlp.cv_results_['mean_test_score']
    stds = gs_mlp.cv_results_['std_test_score']
    for mean, std, params in zip(means, stds, gs_mlp.cv_results_['params']):
        print("%0.3f (+/-%0.03f) for %r"
              % (mean, std * 2, params))
    print()
    
    clf_mlp= gs_mlp.best_estimator_

#Get Final Scores
    clf_mlp.fit(X_train, y_train)
    scores = cross_val_score(estimator= clf_mlp,
                         X=X_train,
                         y=y_train,
                         cv=10,
                         n_jobs=1)
    
    print('--> Final Model Training Accuracy score: %.3f +/- %.3f' %(np.mean(scores), np.std(scores)))
    print()
    print('--> Final Accuracy score on Test set: %.5f' %  clf_mlp.score(X_test,y_test))

    y_true, y_pred = y_test,  clf_mlp.predict(X_test)
 
    confmat = confusion_matrix(y_true, y_pred)
   
    print()
    print("Confusion matrix:")
    print(confusion_matrix(y_true, y_pred))
    print()
    print("Detailed classification report:")
    print(classification_report(y_true, y_pred))
    print()
    
    pipelines.append(( 'MLP', clf_mlp))
    
    fig, ax = plt.subplots(figsize=(2.5, 2.5))
    ax.matshow(confmat, cmap=plt.cm.Blues, alpha=0.3)
("%0.3f (+/-%0.03f) for %r" % (mean, std * 2, params))
# Out:
# Best parameters found:
#  {'activation': 'tanh', 'alpha': 0.0001, 'hidden_layer_sizes': (100, 50, 100), 'learning_rate': 'constant', 'solver': 'sgd'}
# 0.8368263473053892

# %%
#y_true, y_pred = y_test , gs_mlp.predict(X_test)

#from sklearn.metrics import classification_report
#print('Results on the test set:')
#print(classification_report(y_true, y_pred))

gs_mlp.fit(X_train, y_train)
y_pred_mlp = gs_mlp.predict(X_test)
confmat_mlp = confusion_matrix(y_true=y_test, y_pred=y_pred_mlp)

print(accuracy_score(y_test, y_pred_mlp))
print(confusion_matrix(y_test, y_pred_mlp))
print(classification_report(y_test, y_pred_mlp))
# Out:
# 0.75
# [[69 17]
#  [25 57]]
#               precision    recall  f1-score   support
#
#            0       0.73      0.80      0.77        86
#            1       0.77      0.70      0.73        82
#
#    micro avg       0.75      0.75      0.75       168
#    macro avg       0.75      0.75      0.75       168
# weighted avg       0.75      0.75      0.75       168

# %%
fig, ax = plt.subplots(figsize=(2.5, 2.5))
ax.matshow(confmat_mlp, cmap=plt.cm.Blues, alpha=0.3)
for i in range(confmat_mlp.shape[0]):
    for j in range(confmat_mlp.shape[1]):
        ax.text(x=j, y=i, s=confmat_mlp[i, j], va='center', ha='center')

plt.xlabel('predicted label')
plt.ylabel('true label')

plt.tight_layout()
plt.show()

# %%
#Using GridSearch to optimise for Accuracy
gs_mlp =GridSearchCV(mlp, parameter_space, n_jobs=-1, cv=3,scoring='f1')

#Fitting Gridsearch to the training data
gs_mlp = gs_mlp.fit(X_train, y_train)

# Best parameters set
print('Best parameters found:\n', gs_mlp.best_params_)

# All results
means = gs_mlp.cv_results_['mean_test_score']
stds = gs_mlp.cv_results_['std_test_score']
for mean, std, params in zip(means, stds, gs_mlp.cv_results_['params']):
    print("%0.3f (+/-%0.03f) for %r" % (mean, std * 2, params))
# Out:
# Best parameters found:
#  {'activation': 'relu', 'alpha': 0.01, 'hidden_layer_sizes': (100, 100, 100), 'learning_rate': 'adaptive', 'solver': 'adam'}
# 0.752 (+/-0.063) for {'activation': 'tanh', 'alpha': 0.0001, 'hidden_layer_sizes': (50, 50, 50), 'learning_rate': 'constant', 'solver': 'sgd'}
# 0.823 (+/-0.047) for {'activation': 'tanh', 'alpha': 0.0001, 'hidden_layer_sizes': (50, 50, 50), 'learning_rate': 'constant', 'solver': 'adam'}
# 0.825 (+/-0.054) for {'activation': 'tanh', 'alpha': 0.0001, 'hidden_layer_sizes': (50, 50, 50), 'learning_rate': 'adaptive', 'solver': 'sgd'}
# 0.821 (+/-0.061) for {'activation': 'tanh', 'alpha': 0.0001, 'hidden_layer_sizes': (50, 50, 50), 'learning_rate': 'adaptive', 'solver': 'adam'}
# 0.759 (+/-0.115) for {'activation': 'tanh', 'alpha': 0.0001, 'hidden_layer_sizes': (50, 100, 50), 'learning_rate': 'constant', 'solver': 'sgd'}
# 0.801 (+/-0.078) for {'activation': 'tanh', 'alpha': 0.0001, 'hidden_layer_sizes': (50, 100, 50), 'learning_rate': 'constant', 'solver': 'adam'}
# 0.689 (+/-0.320) for {'activation': 'tanh', 'alpha': 0.0001, 'hidden_layer_sizes': (50, 100, 50), 'learning_rate': 'adaptive', 'solver': 'sgd'}
# 0.815 (+/-0.065) for {'activation': 'tanh', 'alpha': 0.0001, 'hidden_layer_sizes': (50, 100, 50), 'learning_rate': 'adaptive', 'solver': 'adam'}
# 0.772 (+/-0.153) for {'activation': 'tanh', 'alpha': 0.0001, 'hidden_layer_sizes': (100, 100, 100), 'learning_rate': 'constant', 'solver': 'sgd'}
# 0.817 (+/-0.075) for {'activation': 'tanh', 'alpha': 0.0001, 'hidden_layer_sizes': (100, 100, 100), 'learning_rate': 'constant', 'solver': 'adam'}
# 0.776 (+/-0.118) for {'activation': 'tanh', 'alpha': 0.0001, 'hidden_layer_sizes': (100, 100, 100), 'learning_rate': 'adaptive', 'solver': 'sgd'}
# 0.820 (+/-0.073) for {'activation': 'tanh', 'alpha': 0.0001, 'hidden_layer_sizes': (100, 100, 100), 'learning_rate': 'adaptive', 'solver': 'adam'}
# 0.768 (+/-0.119) for {'activation': 'tanh', 'alpha': 0.0001, 'hidden_layer_sizes': (100, 50, 100), 'learning_rate': 'constant', 'solver': 'sgd'}
# 0.834 (+/-0.051) for {'activation': 'tanh', 'alpha': 0.0001, 'hidden_layer_sizes': (100, 50, 100), 'learning_rate': 'constant', 'solver': 'adam'}
# 0.605 (+/-0.561) for {'activation': 'tanh', 'alpha': 0.0001, 'hidden_layer_sizes': (100, 50, 100), 'learning_rate': 'adaptive', 'solver': 'sgd'}
# 0.825 (+/-0.039) for {'activation': 'tanh', 'alpha': 0.0001, 'hidden_layer_sizes': (100, 50, 100), 'learning_rate': 'adaptive', 'solver': 'adam'}
# 0.698 (+/-0.122) for {'activation': 'tanh', 'alpha': 0.001, 'hidden_layer_sizes': (50, 50, 50), 'learning_rate': 'constant', 'solver': 'sgd'}
# 0.824 (+/-0.060) for {'activation': 'tanh', 'alpha': 0.001, 'hidden_layer_sizes': (50, 50, 50), 'learning_rate': 'constant', 'solver': 'adam'}
# 0.746 (+/-0.108) for {'activation': 'tanh', 'alpha': 0.001, 'hidden_layer_sizes': (50, 50, 50), 'learning_rate': 'adaptive', 'solver': 'sgd'}
# 0.831 (+/-0.055) for {'activation': 'tanh', 'alpha': 0.001, 'hidden_layer_sizes': (50, 50, 50), 'learning_rate': 'adaptive', 'solver': 'adam'}
# 0.752 (+/-0.153) for {'activation': 'tanh', 'alpha': 0.001, 'hidden_layer_sizes': (50, 100, 50), 'learning_rate': 'constant', 'solver': 'sgd'}
# 0.819 (+/-0.044) for {'activation': 'tanh', 'alpha': 0.001, 'hidden_layer_sizes': (50, 100, 50), 'learning_rate': 'constant', 'solver': 'adam'}
# 0.768 (+/-0.028) for {'activation': 'tanh', 'alpha': 0.001, 'hidden_layer_sizes': (50, 100, 50), 'learning_rate': 'adaptive', 'solver': 'sgd'}
# 0.824 (+/-0.078) for {'activation': 'tanh', 'alpha': 0.001, 'hidden_layer_sizes': (50, 100, 50), 'learning_rate': 'adaptive', 'solver': 'adam'}
# 0.757 (+/-0.088) for {'activation': 'tanh', 'alpha': 0.001, 'hidden_layer_sizes': (100, 100, 100), 'learning_rate': 'constant', 'solver': 'sgd'}
# 0.822 (+/-0.070) for {'activation': 'tanh', 'alpha': 0.001, 'hidden_layer_sizes': (100, 100, 100), 'learning_rate': 'constant', 'solver': 'adam'}
# 0.662 (+/-0.054) for {'activation': 'tanh', 'alpha': 0.001, 'hidden_layer_sizes': (100, 100, 100), 'learning_rate': 'adaptive', 'solver': 'sgd'}
# 0.821 (+/-0.068) for {'activation': 'tanh', 'alpha': 0.001, 'hidden_layer_sizes': (100, 100, 100), 'learning_rate': 'adaptive', 'solver': 'adam'}
# 0.772 (+/-0.032) for {'activation': 'tanh', 'alpha': 0.001, 'hidden_layer_sizes': (100, 50, 100), 'learning_rate': 'constant', 'solver': 'sgd'}
# 0.827 (+/-0.055) for {'activation': 'tanh', 'alpha': 0.001, 'hidden_layer_sizes': (100, 50, 100), 'learning_rate': 'constant', 'solver': 'adam'}
# 0.699 (+/-0.059) for {'activation': 'tanh', 'alpha': 0.001, 'hidden_layer_sizes': (100, 50, 100), 'learning_rate': 'adaptive', 'solver': 'sgd'}
# 0.810 (+/-0.079) for {'activation': 'tanh', 'alpha': 0.001, 'hidden_layer_sizes': (100, 50, 100), 'learning_rate': 'adaptive', 'solver': 'adam'}
# 0.732 (+/-0.116) for {'activation': 'tanh', 'alpha': 0.01, 'hidden_layer_sizes': (50, 50, 50), 'learning_rate': 'constant', 'solver': 'sgd'}
# 0.823 (+/-0.071) for {'activation': 'tanh', 'alpha': 0.01, 'hidden_layer_sizes': (50, 50, 50), 'learning_rate': 'constant', 'solver': 'adam'}
# 0.680 (+/-0.070) for {'activation': 'tanh', 'alpha': 0.01, 'hidden_layer_sizes': (50, 50, 50), 'learning_rate': 'adaptive', 'solver': 'sgd'}
# 0.834 (+/-0.046) for {'activation': 'tanh', 'alpha': 0.01, 'hidden_layer_sizes': (50, 50, 50), 'learning_rate': 'adaptive', 'solver': 'adam'}
# 0.518 (+/-0.564) for {'activation': 'tanh', 'alpha': 0.01, 'hidden_layer_sizes': (50, 100, 50), 'learning_rate': 'constant', 'solver': 'sgd'}
# 0.819 (+/-0.069) for {'activation': 'tanh', 'alpha': 0.01, 'hidden_layer_sizes': (50, 100, 50), 'learning_rate': 'constant', 'solver': 'adam'}
# 0.582 (+/-0.492) for {'activation': 'tanh', 'alpha': 0.01, 'hidden_layer_sizes': (50, 100, 50), 'learning_rate': 'adaptive', 'solver': 'sgd'}
# 0.824 (+/-0.060) for {'activation': 'tanh', 'alpha': 0.01, 'hidden_layer_sizes': (50, 100, 50), 'learning_rate': 'adaptive', 'solver': 'adam'}
# 0.765 (+/-0.162) for {'activation': 'tanh', 'alpha': 0.01, 'hidden_layer_sizes': (100, 100, 100), 'learning_rate': 'constant', 'solver': 'sgd'}
# 0.824 (+/-0.079) for {'activation': 'tanh', 'alpha': 0.01, 'hidden_layer_sizes': (100, 100, 100), 'learning_rate': 'constant', 'solver': 'adam'}
# 0.789 (+/-0.065) for {'activation': 'tanh', 'alpha': 0.01, 'hidden_layer_sizes': (100, 100, 100), 'learning_rate': 'adaptive', 'solver': 'sgd'}
# 0.825 (+/-0.045) for {'activation': 'tanh', 'alpha': 0.01, 'hidden_layer_sizes': (100, 100, 100), 'learning_rate': 'adaptive', 'solver': 'adam'}
# 0.714 (+/-0.109) for {'activation': 'tanh', 'alpha': 0.01, 'hidden_layer_sizes': (100, 50, 100), 'learning_rate': 'constant', 'solver': 'sgd'}
# 0.823 (+/-0.053) for {'activation': 'tanh', 'alpha': 0.01, 'hidden_layer_sizes': (100, 50, 100), 'learning_rate': 'constant', 'solver': 'adam'}
# 0.794 (+/-0.022) for {'activation': 'tanh', 'alpha': 0.01, 'hidden_layer_sizes': (100, 50, 100), 'learning_rate': 'adaptive', 'solver': 'sgd'}
# 0.817 (+/-0.084) for {'activation': 'tanh', 'alpha': 0.01, 'hidden_layer_sizes': (100, 50, 100), 'learning_rate': 'adaptive', 'solver': 'adam'}
# 0.454 (+/-0.663) for {'activation': 'tanh', 'alpha': 0.05, 'hidden_layer_sizes': (50, 50, 50), 'learning_rate': 'constant', 'solver': 'sgd'}
# 0.819 (+/-0.093) for {'activation': 'tanh', 'alpha': 0.05, 'hidden_layer_sizes': (50, 50, 50), 'learning_rate': 'constant', 'solver': 'adam'}
# 0.758 (+/-0.050) for {'activation': 'tanh', 'alpha': 0.05, 'hidden_layer_sizes': (50, 50, 50), 'learning_rate': 'adaptive', 'solver': 'sgd'}
# 0.817 (+/-0.055) for {'activation': 'tanh', 'alpha': 0.05, 'hidden_layer_sizes': (50, 50, 50), 'learning_rate': 'adaptive', 'solver': 'adam'}
# 0.772 (+/-0.115) for {'activation': 'tanh', 'alpha': 0.05, 'hidden_layer_sizes': (50, 100, 50), 'learning_rate': 'constant', 'solver': 'sgd'}
# 0.820 (+/-0.074) for {'activation': 'tanh', 'alpha': 0.05, 'hidden_layer_sizes': (50, 100, 50), 'learning_rate': 'constant', 'solver': 'adam'}
# 0.696 (+/-0.249) for {'activation': 'tanh', 'alpha': 0.05, 'hidden_layer_sizes': (50, 100, 50), 'learning_rate': 'adaptive', 'solver': 'sgd'}
# 0.827 (+/-0.064) for {'activation': 'tanh', 'alpha': 0.05, 'hidden_layer_sizes': (50, 100, 50), 'learning_rate': 'adaptive', 'solver': 'adam'}
# 0.546 (+/-0.775) for {'activation': 'tanh', 'alpha': 0.05, 'hidden_layer_sizes': (100, 100, 100), 'learning_rate': 'constant', 'solver': 'sgd'}
# 0.808 (+/-0.078) for {'activation': 'tanh', 'alpha': 0.05, 'hidden_layer_sizes': (100, 100, 100), 'learning_rate': 'constant', 'solver': 'adam'}
# 0.814 (+/-0.075) for {'activation': 'tanh', 'alpha': 0.05, 'hidden_layer_sizes': (100, 100, 100), 'learning_rate': 'adaptive', 'solver': 'sgd'}
# 0.816 (+/-0.095) for {'activation': 'tanh', 'alpha': 0.05, 'hidden_layer_sizes': (100, 100, 100), 'learning_rate': 'adaptive', 'solver': 'adam'}
# 0.748 (+/-0.196) for {'activation': 'tanh', 'alpha': 0.05, 'hidden_layer_sizes': (100, 50, 100), 'learning_rate': 'constant', 'solver': 'sgd'}
# 0.819 (+/-0.067) for {'activation': 'tanh', 'alpha': 0.05, 'hidden_layer_sizes': (100, 50, 100), 'learning_rate': 'constant', 'solver': 'adam'}
# 0.775 (+/-0.116) for {'activation': 'tanh', 'alpha': 0.05, 'hidden_layer_sizes': (100, 50, 100), 'learning_rate': 'adaptive', 'solver': 'sgd'}
# 0.816 (+/-0.062) for {'activation': 'tanh', 'alpha': 0.05, 'hidden_layer_sizes': (100, 50, 100), 'learning_rate': 'adaptive', 'solver': 'adam'}
# 0.793 (+/-0.024) for {'activation': 'tanh', 'alpha': 1, 'hidden_layer_sizes': (50, 50, 50), 'learning_rate': 'constant', 'solver': 'sgd'}
# 0.805 (+/-0.089) for {'activation': 'tanh', 'alpha': 1, 'hidden_layer_sizes': (50, 50, 50), 'learning_rate': 'constant', 'solver': 'adam'}
# 0.749 (+/-0.108) for {'activation': 'tanh', 'alpha': 1, 'hidden_layer_sizes': (50, 50, 50), 'learning_rate': 'adaptive', 'solver': 'sgd'}
# 0.814 (+/-0.083) for {'activation': 'tanh', 'alpha': 1, 'hidden_layer_sizes': (50, 50, 50), 'learning_rate': 'adaptive', 'solver': 'adam'}
# 0
random_state=None,
#     svd_solver='auto', tol=0.0, whiten=False)), ('clf', MLPClassifier(activation='relu', alpha=0.0001, batch_size='auto', beta_1=0.9,
#          beta_2...=True, solver='adam', tol=0.0001,
#          validation_fraction=0.1, verbose=False, warm_start=False))])),
#  ('SMLP',
#   MLPClassifier(activation='relu', alpha=0.0001, batch_size='auto', beta_1=0.9,
#          beta_2=0.999, early_stopping=False, epsilon=1e-08,
#          hidden_layer_sizes=(100,), learning_rate='constant',
#          learning_rate_init=0.001, max_iter=100, momentum=0.9,
#          n_iter_no_change=10, nesterovs_momentum=True, power_t=0.5,
#          random_state=None, shuffle=True, solver='adam', tol=0.0001,
#          validation_fraction=0.1, verbose=False, warm_start=False)),
#  ('SMLP',
#   MLPClassifier(activation='relu', alpha=0.0001, batch_size='auto', beta_1=0.9,
#          beta_2=0.999, early_stopping=False, epsilon=1e-08,
#          hidden_layer_sizes=(100,), learning_rate='constant',
#          learning_rate_init=0.001, max_iter=100, momentum=0.9,
#          n_iter_no_change=10, nesterovs_momentum=True, power_t=0.5,
#          random_state=None, shuffle=True, solver='adam', tol=0.0001,
#          validation_fraction=0.1, verbose=False, warm_start=False)),
#  ('SMLP',
#   MLPClassifier(activation='relu', alpha=0.0001, batch_size='auto', beta_1=0.9,
#          beta_2=0.999, early_stopping=False, epsilon=1e-08,
#          hidden_layer_sizes=(100,), learning_rate='constant',
#          learning_rate_init=0.001, max_iter=100, momentum=0.9,
#          n_iter_no_change=10, nesterovs_momentum=True, power_t=0.5,
#          random_state=None, shuffle=True, solver='adam', tol=0.0001,
#          validation_fraction=0.1, verbose=False, warm_start=False)),
#  ('SMLP',
#   MLPClassifier(activation='relu', alpha=0.0001, batch_size='auto', beta_1=0.9,
#          beta_2=0.999, early_stopping=False, epsilon=1e-08,
#          hidden_layer_sizes=(100,), learning_rate='constant',
#          learning_rate_init=0.001, max_iter=100, momentum=0.9,
#          n_iter_no_change=10, nesterovs_momentum=True, power_t=0.5,
#          random_state=None, shuffle=True, solver='adam', tol=0.0001,
#          validation_fraction=0.1, verbose=False, warm_start=False)),
#  ('SMLP',
#   MLPClassifier(activation='relu', alpha=0.0001, batch_size='auto', beta_1=0.9,
#          beta_2=0.999, early_stopping=False, epsilon=1e-08,
#          hidden_layer_sizes=(100,), learning_rate='constant',
#          learning_rate_init=0.001, max_iter=100, momentum=0.9,
#          n_iter_no_change=10, nesterovs_momentum=True, power_t=0.5,
#          random_state=None, shuffle=True, solver='adam', tol=0.0001,
#          validation_fraction=0.1, verbose=False, warm_start=False)),
#  ('svc_pipeline', Pipeline(memory=None,
#        steps=[('scl', StandardScaler(copy=True, with_mean=True, with_std=True)), ('pca', PCA(copy=True, iterated_power='auto', n_components=3, random_state=None,
#     svd_solver='auto', tol=0.0, whiten=False)), ('clf', SVC(C=1.0, cache_size=200, class_weight=None, coef0=0.0,
#     decision_function_shape='ovr', degree=3, gamma='auto_deprecated',
#     kernel='rbf', max_iter=-1, probability=True, random_state=None,
#     shrinking=True, tol=0.001, verbose=False))])),
#  ('MLP',
#   MLPClassifier(activation='relu', alpha=0.0001, batch_size='auto', beta_1=0.9,
#          beta_2=0.999, early_stopping=False, epsilon=1e-08,
#          hidden_layer_sizes=(100,), learning_rate='constant',
#          learning_rate_init=0.001, max_iter=100, momentum=0.9,
#          n_iter_no_change=10, nesterovs_momentum=True, power_t=0.5,
#          random_state=None, shuffle=True, solver='adam', tol=0.0001,
#          validation_fraction=0.1, verbose=False, warm_start=False))]

# %%
results = []
names = []
scoring = 'accuracy'
for name, model in pipelines:
    cv_results = cross_val_score(model, X_train, y_train, cv=10,scoring=scoring)
    results.append(cv_results)
    names.append(name)
    msg = "%s: %f (%f)" % (name, cv_results.mean(), cv_results.std())
    print(msg)
# Out:
# ScaledDummy: 0.511987 (0.003698)
# ScaledMLP: 0.813052 (0.035937)
# ScaledDummy: 0.511987 (0.003698)
# ScaledMLP: 0.816059 (0.038820)
# SMLP: 0.820580 (0.042885)
# SMLP: 0.826574 (0.049427)
# SMLP: 0.811580 (0.038698)
# SMLP: 0.817595 (0.048752)
# SMLP: 0.823543 (0.042474)
# svc_pipeline: 0.811714 (0.048797)
# MLP: 0.820670 (0.051092)

# %%
# Compare Algorithms
fig = plt.figure()
fig.suptitle( 'Scaled Algorithm Comparison' )
ax = fig.add_subplot(111)
plt.boxplot(results)
ax.set_xticklabels(names)
plt.show()

# %%
from sklearn.metrics import roc_curve, auc
from sklearn.metrics import roc_auc_score

fig = plt.figure(figsize=(8, 6))
all_tpr = []

for name, model in pipelines:
      
    model.fit(X_train, y_train)
    
    probas = model.predict_proba(X_test)
    fpr, tpr, thresholds = roc_curve(y_test, probas[:, 1], pos_label=1)
    roc_auc = auc(fpr, tpr)
    current_auc = str('%.2f' %roc_auc)
    
    plt.plot(fpr, 
             tpr, 
             lw=1, 
             label= str(name + ' AUC: ' + current_auc))

plt.plot([0, 1], 
         [0, 1], 
         linestyle='--', 
         color=(0.6, 0.6, 0.6), 
         label='random guessing')

plt.plot([0, 0, 1], 
         [0, 1, 1], 
         lw=2, 
         linestyle=':', 
         color='black', 
         label='perfect performance')

plt.xlim([-0.05, 1.05])
plt.ylim([-0.05, 1.05])
plt.xlabel('false positive rate')
plt.ylabel('true positive rate')
plt.title('Receiver Operator Characteristic')
plt.legend(loc="lower right")

plt.tight_layout()
plt.show()

# %%
mlp = MLPClassifier(hidden_layer_sizes=(100,), max_iter=10, solver='sgd', tol=1e-4, random_state=1,
                    learning_rate_init=.1)

# %%
mlp.fit(X_train, y_train)
print("Training set score: %f" % mlp.score(X_train, y_train))
print("Test set score: %f" % mlp.score(X_test, y_test))
# Out:
# Training set score: 0.839820
# Test set score: 0.750000

# %%
mlp = MLPClassifier(hidden_layer_sizes=(100, 100), max_iter=500, alpha=0.009,
                    activation='logistic', verbose=10, tol=1e-4, random_state=1, momentum=0.5,epsilon=1e-08)
mlp.fit(X_train, y_train)
print("\nTraining set score: %f" % mlp.score(X_train, y_train))
print("Test set score: %f" % mlp.score(X_test, y_test))
# Out:
# Iteration 1, loss = 0.70303297
# Iteration 2, loss = 0.69346462
# Iteration 3, loss = 0.68998746
# Iteration 4, loss = 0.68595414
# Iteration 5, loss = 0.68242616
# Iteration 6, loss = 0.67860386
# Iteration 7, loss = 0.67267781
# Iteration 8, loss = 0.66887036
# Iteration 9, loss = 0.66376722
# Iteration 10, loss = 0.65532435
# Iteration 11, loss = 0.64890803
# Iteration 12, loss = 0.64150625
# Iteration 13, loss = 0.63059092
# Iteration 14, loss = 0.62147945
# Iteration 15, loss = 0.61212383
# Iteration 16, loss = 0.60185280
# Iteration 17, loss = 0.59050679
# Iteration 18, loss = 0.57817668
# Iteration 19, loss = 0.56569667
# Iteration 20, loss = 0.55423229
# Iteration 21, loss = 0.54237438
# Iteration 22, loss = 0.53330781
# Iteration 23, loss = 0.52132954
# Iteration 24, loss = 0.51200206
# Iteration 25, loss = 0.50235580
# Iteration 26, loss = 0.49327700
# Iteration 27, loss = 0.48816885
# Iteration 28, loss = 0.47813598
# Iteration 29, loss = 0.47175115
# Iteration 30, loss = 0.47038667
# Iteration 31, loss = 0.46012304
# Iteration 32, loss = 0.45596865
# Iteration 33, loss = 0.44919776
# Iteration 34, loss = 0.44687774
# Iteration 35, loss = 0.44077523
# Iteration 36, loss = 0.43951746
# Iteration 37, loss = 0.43586938
# Iteration 38, loss = 0.43159743
# Iteration 39, loss = 0.43055453
# Iteration 40, loss = 0.42737057
# Iteration 41, loss = 0.42618721
# Iteration 42, loss = 0.42454217
# Iteration 43, loss = 0.42489767
# Iteration 44, loss = 0.42183229
# Iteration 45, loss = 0.42157595
# Iteration 46, loss = 0.42164597
# Iteration 47, loss = 0.42058423
# Iteration 48, loss = 0.41803456
# Iteration 49, loss = 0.41747937
# Iteration 50, loss = 0.42042708
# Iteration 51, loss = 0.41574693
# Iteration 52, loss = 0.41768360
# Iteration 53, loss = 0.41831645
# Iteration 54, loss = 0.41621351
# Iteration 55, loss = 0.41685344
# Iteration 56, loss = 0.41366866
# Iteration 57, loss = 0.41765372
# Iteration 58, loss = 0.41339874
# Iteration 59, loss = 0.41709660
# Iteration 60, loss = 0.41318011
# Iteration 61, loss = 0.41410629
# Iteration 62, loss = 0.41300529
# Iteration 63, loss = 0.41265204
# Iteration 64, loss = 0.41376230
# Iteration 65, loss = 0.41184769
# Iteration 66, loss = 0.41350759
# Iteration 67, loss = 0.41213544
# Iteration 68, loss = 0.41308026
# Iteration 69, loss = 0.41423410
# Iteration 70, loss = 0.41197585
# Iteration 71, loss = 0.41614059
# Iteration 72, loss = 0.41048613
# Iteration 73, loss = 0.42025001
# Iteration 74, loss = 0.41364078
# Iteration 75, loss = 0.41809438
# Iteration 76, loss = 0.41213199
# Iteration 77, loss = 0.41239220
# Iteration 78, loss = 0.41104908
# Iteration 79, loss = 0.41181668
# Iteration 80, loss = 0.41070582
# Iteration 81, loss = 0.41100193
# Iteration 82, loss = 0.41063614
# Iteration 83, loss = 0.41156248
# Training loss did not improve more than tol=0.000100 for 10 consecutive epochs. Stopping.
#
# Training set score: 0.826347
# Test set score: 0.755952

# %%
prediction = mlp.predict(X_test)
from sklearn.metrics import classification_report,confusion_matrix
print(confusion_matrix(y_test,prediction))
# Out:
# [[68 18]
#  [23 59]]

# %%
# plot the result
#Class
# Now let's compare a few different regularization performances on the dataset:
weights = [None, 'balanced', {1:1, 0:1}, {1:2, 0:1}, {1:5, 0:1}, {1:10, 0:1}] #in the first case weighting 1 for yes and 1 for no
# by default both equal, then assign yes x2 weight and no still just one weight 
#1:10 gives the best results means that it is best suited to predictign yes answers, not good at predicting no-s 
names = ['None', 'Balanced', '1 to 1', '2 to 2', '5 to 1', '10 to 1']
colors = sns.color_palette("Set2")

plt.figure(figsize=(10,8))

for n, weight in enumerate(weights):
    #Fit a model
    logreg = LogisticRegression(fit_intercept = False, C = 1e12, class_weight=weight) #Starter code
    model_log = logreg.fit(X_train, y_train)
    print(model_log) #Preview model params

    #Predict
    y_hat_test = logreg.predict(X_test)

    y_score = logreg.fit(X_train, y_train).decision_function(X_test)

    fpr, tpr, thresholds = roc_curve(y_test, y_score)
    
    print('AUC for {}: {}'.format(names[n], auc(fpr, tpr)))
    lw = 2
    plt.plot(fpr, tpr, color=colors[n],
             lw=lw, label='ROC curve {}'.format(names[n]))
plt.plot([0, 1], [0, 1], color='navy', lw=lw, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])

plt.yticks([i/20.0 for i in range(21)])
plt.xticks([i/20.0 for i in range(21)])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver operating characteristic (ROC) Curve')
plt.legend(loc="lower right")
plt.show()

# %%
## http://scikit-learn.org/stable/modules/svm.html
from sklearn import svm
clf = svm.SVC(C=10, kernel='linear',gamma = 1, degree = 4, random_state = 1)
clf.fit(X_train, y_train)

# %%
prediction = clf.predict(X_test)
from sklearn.metrics import classification_report,confusion_matrix
print(confusion_matrix(y_test,prediction))

# %%
clf.support_vectors_

# %%
#Make Support Vector Classifier Pipeline
pipe_svc = Pipeline([('scl', StandardScaler()),
                     ('pca', PCA(n_components=1)),
                     ('clf', SVC(probability=True, verbose=False))])

#Fit Pipeline to training Data
pipe_svc.fit(X_train, y_train)

#print('--> Fitted Pipeline to training Data')

scores = cross_val_score(estimator=pipe_svc, X=X_train, y=y_train, cv=num_folds, n_jobs=1, verbose=0)
print('--> Model Training Accuracy: %.3f +/- %.3f' %(np.mean(scores), np.std(scores)))

#Tune Hyperparameters
param_range = [0.001, 0.01, 0.1, 1.0, 10.0, 100.0, 1000.0]
param_grid = [{'clf__C': param_range,'clf__kernel': ['linear']},
              {'clf__C': param_range,'clf__gamma': param_range,
               'clf__kernel': ['rbf']}]

gs_svc = GridSearchCV(estimator=pipe_svc,
                  param_grid=param_grid,
                  scoring='accuracy',
                  cv=num_folds,
                  n_jobs=1)
gs_svc = gs_svc.fit(X_train, y_train)
print('--> Tuned Parameters Best Score: ',gs_svc.best_score_)
print('--> Best Parameters: \n',gs_svc.best_params_)

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

import pandas as pd
import numpy as np
from sklearn.dummy import DummyClassifier
from sklearn.model_selection import train_test_split
from sklearn.model_selection import cross_val_score
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
from sklearn.pipeline import Pipeline
from sklearn.model_selection import GridSearchCV

from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.svm import SVC
from sklearn.metrics import confusion_matrix
from sklearn.metrics import accuracy_score
from sklearn.metrics import classification_report

pipelines = []

pipe_knn = Pipeline([('scl', StandardScaler()),
                     ('pca', PCA(n_components=1)),
                     ('clf', KNeighborsClassifier())])

pipe_svc = Pipeline([('scl', StandardScaler()),
                     ('pca', PCA(n_components=1)),
                     ('clf', SVC(probability=True, verbose=False))])

pipe_DT = Pipeline([('scl', StandardScaler()),
                     ('pca', PCA(n_components=1)),
                     ('clf', DecisionTreeClassifier())])

pipe_NB = Pipeline([('scl', StandardScaler()),
                     ('pca', PCA(n_components=1)),
                     ('clf', GaussianNB())])


pipelines.append(( 'ScaledKNN' , pipe_knn))
pipelines.append(( 'ScaledSVM' , pipe_svc))
pipelines.append(( 'ScaledDT' , pipe_DT))
pipelines.append(( 'ScaledNB' , pipe_NB))

# %%
pipe_Dummy = Pipeline([('scl', StandardScaler()), #not needed because most frequent class label used for prediction only
                     ('clf', DummyClassifier(strategy="most_frequent"))])

pipe_MLP = Pipeline([('scl', StandardScaler()),
                     ('pca', PCA(n_components=1)),
                     ('clf', MLPClassifier(hidden_layer_sizes=(10, 10), max_iter=750, alpha=1e-4,
                    activation='logistic', tol=1e-4, random_state=1, verbose=False))])

pipelines.append(( 'ScaledDummy', pipe_Dummy))
pipelines.append(( 'ScaledMLP', pipe_MLP))

# %%
num_folds = 10
scoring = 'accuracy'
results = []
names = []
for name, model in pipelines:
    cv_results = cross_val_score(model, X_train, y_train, cv=num_folds, scoring=scoring)
    results.append(cv_results)
    names.append(name)
    msg = "%s: %f (%f)" % (name, cv_results.mean(), cv_results.std())
    print(msg)

# %%
# Compare Algorithms
fig = plt.figure(figsize=(20,16))
fig.suptitle( 'Scaled Algorithm Comparison' )
ax = fig.add_subplot(111)
plt.boxplot(results)
ax.set_xticklabels(names)
plt.show()

# %%
#Make Support Vector Classifier Pipeline
pipe_svc = Pipeline([('scl', StandardScaler()),
                     ('pca', PCA(n_components=1)),
                     ('clf', SVC(probability=True, verbose=False))])

#Fit Pipeline to training Data
pipe_svc.fit(X_train, y_train)

#print('--> Fitted Pipeline to training Data')

scores = cross_val_score(estimator=pipe_svc, X=X_train, y=y_train, cv=num_folds, n_jobs=1, verbose=0)
print('--> Model Training Accuracy: %.3f +/- %.3f' %(np.mean(scores), np.std(scores)))

#Tune Hyperparameters
param_range = [0.001, 0.01, 0.1, 1.0, 10.0, 100.0, 1000.0]
param_grid = [{'clf__C': param_range,'clf__kernel': ['linear']},
              {'clf__C': param_range,'clf__gamma': param_range,
               'clf__kernel': ['rbf']}]

gs_svc = GridSearchCV(estimator=pipe_svc,
                  param_grid=param_grid,
                  scoring='accuracy',
                  cv=num_folds,
                  n_jobs=1)
gs_svc = gs_svc.fit(X_train, y_train)
print('--> Tuned Parameters Best Score: ',gs_svc.best_score_)
print('--> Best Parameters: \n',gs_svc.best_params_)
import warnings
warnings.filterwarnings("ignore")

# %%
~
